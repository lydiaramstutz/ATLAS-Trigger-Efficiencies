# %%
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pathlib import Path
# folder containing: jet80, jet170, jet1000, lep80, lep170, lep1000
file_path = Path("/Users/lydiaamstutz/Downloads/jet80update.root")
sample_label = "jet80"
print("Opening:", file_path)
file = uproot.open(file_path)
print("File keys:", file.keys())
# Out:
# Opening: /Users/lydiaamstutz/Downloads/jet80update.root
# File keys: ['EventLoop_OutputStream_ANALYSIS;1', 'EventLoop_FileExecuted;1', 'EventLoop_JobStats;1', 'listOfSystematics;1', 'metadata;1', 'cflow_AnaElectrons_tight_NOSYS;1', 'cflow_AnaMuons_tight_NOSYS;1', 'cflow_AnaTauJets_tight_NOSYS;1', 'cflow_AnaJets_baselineJvt_NOSYS;1', 'cflow_EventInfo__TAUJETcommon_NOSYS;1', 'cflow_EventInfo__TAUELcommon_NOSYS;1', 'cflow_EventInfo__TAUMUcommon_NOSYS;1', 'cflow_EventInfo__DILEPcommon_NOSYS;1', 'CutBookkeeper_569178_450000_NOSYS;1', 'EventLoop_RunTime;1', 'EventLoop_EventCount;1', 'reco;1']

# %%
# try the expected tree first
if "reco" in file:
    tree = file["reco"]
else:
    # show what trees exist so i can pick the right one
    print("Top-level keys:", file.keys())
    raise KeyError("Tree 'reco' not found. Pick the correct tree from file.keys().")

print("Tree loaded:", tree)
print("N entries:", tree.num_entries)
# Out:
# Tree loaded: <TTree 'reco' (148 branches) at 0x000160d55d30>
# N entries: 97792

# %%
# find what the tau trigger branches are actually called in this ntuple
keys = tree.keys()
tau_like = [k for k in keys if ("trigPassed_HLT_tau" in k) or ("tau50" in k) or ("mediumRNN" in k)]
print("found", len(tau_like), "tau-ish branches")
for k in tau_like[:80]:
    print(k)
# Out:
# found 8 tau-ish branches
# trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100
# trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25
# trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25
# trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20
# trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50
# trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50
# trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I
# trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40

# %%
# find tau pt branch name in this ntuple
tau_pt_candidates = [k for k in tree.keys() if ("tau" in k.lower()) and ("pt" in k.lower())]
print("tau pt candidates:", tau_pt_candidates)
# Out:
# tau pt candidates: ['tau_truth_pt_invis', 'tau_truth_pt_vis', 'tau_pt_NOSYS']

# %%
# find jet pt branch name in this ntuple
jet_pt_candidates = [k for k in tree.keys() if ("jet" in k.lower()) and ("pt" in k.lower())]
print("jet pt candidates:", jet_pt_candidates)
# Out:
# jet pt candidates: ['jet_pt_NOSYS']

# %%
##check that the file loaded correctly
branches = [
    "eventNumber",
    "met_met_NOSYS",
    "trigPassed_HLT_xe65_cell_xe90_pfopufit_L1XE50",
    "trigPassed_HLT_xe80_cell_xe115_tcpufit_L1XE50",
    "trigPassed_HLT_j70_0eta290_020jvt_bgn160_3j70_pf_ftf_preselj50b85XX3j50_L14J20",
    "trigPassed_HLT_j75_0eta290_020jvt_bgn160_3j75_pf_ftf_preselj50b85XX3j50_L14J20",
    "tau_pt_NOSYS",
    "jet_pt_NOSYS",
    "jet_GN2v01_FixedCutBEff_85_select",
]

#add the taus
branches += [
    "trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50",
    "trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50",
    "trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100",
]

# new triggers in the *update.root file that actually fire on this signal.
# (The 5 new MET triggers xe110_pufit / xe110_pufit_xe70 / xe110_mht /
#  xe90_mht / xe70_mht are present in the file but fire on 0 events across
#  all three mass points -- branches exist but appear unfilled in this MC
#  production, so they're skipped here.)
branches += [
    "trigPassed_HLT_2j35_0eta290_020jvt_bgn160_3j35_pf_ftf_presel3j25XX2j25b85_L15J15p0ETA25",   # J_2J35
    "trigPassed_HLT_2j45_0eta290_020jvt_bgn160_2j45_pf_ftf_presel2j25XX2j25b85_L14J15p0ETA25",   # J_2J45
    "trigPassed_HLT_j140_2j50_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30",   # J140_2J50
    "trigPassed_HLT_j150_2j55_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30",   # J150_2J55
    "trigPassed_HLT_j175_0eta290_020jvt_bgn160_j60_0eta290_020jvt_bgn160_pf_ftf_preselj140b85XXj45b85_L1J100",   # J175_J60
    "trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25",   # DITAU_35_25
    "trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25",   # DITAU_35_25_J
    "trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20",   # DITAU_40_35
    "trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I",   # DITAU_80_35
    "trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40",   # DITAU_80_60
]

arr = tree.arrays(branches, library="ak")
data = {}
for k in branches:
    if arr[k].ndim == 1:
        data[k] = np.array(arr[k])
    else:
        data[k] = arr[k].to_list()

df = pd.DataFrame(data)

offline_met_gev = df["met_met_NOSYS"].values / 1000.0

# %%
print("rows:", len(df))
print("unique events:", df["eventNumber"].nunique())
print("any NaNs in MET:", df["met_met_NOSYS"].isna().any())
print("MET min/max:", df["met_met_NOSYS"].min(), df["met_met_NOSYS"].max())
# Out:
# rows: 97792
# unique events: 97792
# any NaNs in MET: False
# MET min/max: 149.6620330810547 941976.3125

# %%
met_pf = (df["trigPassed_HLT_xe65_cell_xe90_pfopufit_L1XE50"] == 1)
met_hi = (df["trigPassed_HLT_xe80_cell_xe115_tcpufit_L1XE50"] == 1)
j70 = (df["trigPassed_HLT_j70_0eta290_020jvt_bgn160_3j70_pf_ftf_preselj50b85XX3j50_L14J20"] == 1)
j75 = (df["trigPassed_HLT_j75_0eta290_020jvt_bgn160_3j75_pf_ftf_preselj50b85XX3j50_L14J20"] == 1)
tau_tcp = (df["trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50"] == 1)
tau_pf = (df["trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50"] == 1)
tau160 = (df["trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100"] == 1)

# new triggers from the *update.root file
j_2j35 = (df["trigPassed_HLT_2j35_0eta290_020jvt_bgn160_3j35_pf_ftf_presel3j25XX2j25b85_L15J15p0ETA25"] == 1)
j_2j45 = (df["trigPassed_HLT_2j45_0eta290_020jvt_bgn160_2j45_pf_ftf_presel2j25XX2j25b85_L14J15p0ETA25"] == 1)
j140_2j50 = (df["trigPassed_HLT_j140_2j50_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30"] == 1)
j150_2j55 = (df["trigPassed_HLT_j150_2j55_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30"] == 1)
j175_j60 = (df["trigPassed_HLT_j175_0eta290_020jvt_bgn160_j60_0eta290_020jvt_bgn160_pf_ftf_preselj140b85XXj45b85_L1J100"] == 1)
ditau_35_25 = (df["trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25"] == 1)
ditau_35_25_j = (df["trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25"] == 1)
ditau_40_35 = (df["trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20"] == 1)
ditau_80_35 = (df["trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I"] == 1)
ditau_80_60 = (df["trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40"] == 1)

# %%
from itertools import combinations

base = {
    "PF_MET":      met_pf,
    "TCP_MET":     met_hi,
    "J70":         j70,
    "J75":         j75,
    "TAU+MET_PF":  tau_pf,
    "TAU+MET_TCP": tau_tcp,
    "TAU160":      tau160,
    # new triggers
    "J_2J35": j_2j35,
    "J_2J45": j_2j45,
    "J140_2J50": j140_2j50,
    "J150_2J55": j150_2j55,
    "J175_J60": j175_j60,
    "DITAU_35_25": ditau_35_25,
    "DITAU_35_25_J": ditau_35_25_j,
    "DITAU_40_35": ditau_40_35,
    "DITAU_80_35": ditau_80_35,
    "DITAU_80_60": ditau_80_60,
}

# any banch thatfires on 0 events is likely unfilled in
zero_fire = [name for name, m in base.items() if m.sum() == 0]
if zero_fire:
    print("[WARNING] These trigger branches fire on 0 events -- likely unfilled:")
    for n in zero_fire:
        print(f"   - {n}")
    print()

# build all or/and combos
OR = {}
AND = {}
for a, b in combinations(base.keys(), 2):
    OR[f"{a} OR {b}"] = base[a] | base[b]
    AND[f"{a} AND {b}"] = base[a] & base[b]

print(f"Built {len(OR)} OR combos and {len(AND)} AND combos.")

# Overall efficiencies: triggers
print("\n=== Overall efficiencies (Triggers) ===")
for name in base:
    print(f"{name:15s}  eff={base[name].mean():.4f}  passed={base[name].sum()}")

# Overall efficiencies: all ORs
print("\n=== Overall efficiencies (All OR combos) ===")
for name in sorted(OR.keys()):
    print(f"{name:55s} eff={OR[name].mean():.4f}")

# Overall efficiencies: all ANDs
print("\n=== Overall efficiencies (All AND combos) ===")
for name in sorted(AND.keys()):
    print(f"{name:55s} eff={AND[name].mean():.4f}")

# A few specific combos
print("\n=== Specific combos ===")
print("PF_MET OR TAU+MET_PF:", OR["PF_MET OR TAU+MET_PF"].mean())
print("J70 OR TAU+MET_PF:",    OR["J70 OR TAU+MET_PF"].mean())
print("PF_MET OR J70:",        OR["PF_MET OR J70"].mean())
# Out:
# Built 136 OR combos and 136 AND combos.
#
# === Overall efficiencies (Triggers) ===
# PF_MET           eff=0.1464  passed=14314
# TCP_MET          eff=0.0938  passed=9176
# J70              eff=0.0477  passed=4667
# J75              eff=0.0362  passed=3538
# TAU+MET_PF       eff=0.0252  passed=2466
# TAU+MET_TCP      eff=0.0271  passed=2655
# TAU160           eff=0.0072  passed=705
# J_2J35           eff=0.0518  passed=5065
# J_2J45           eff=0.0643  passed=6284
# J140_2J50        eff=0.0336  passed=3283
# J150_2J55        eff=0.0282  passed=2754
# J175_J60         eff=0.0117  passed=1145
# DITAU_35_25      eff=0.0217  passed=2118
# DITAU_35_25_J    eff=0.0172  passed=1683
# DITAU_40_35      eff=0.0093  passed=910
# DITAU_80_35      eff=0.0022  passed=216
# DITAU_80_60      eff=0.0014  passed=138
#
# === Overall efficiencies (All OR combos) ===
# DITAU_35_25 OR DITAU_35_25_J                            eff=0.0232
# DITAU_35_25 OR DITAU_40_35                              eff=0.0224
# DITAU_35_25 OR DITAU_80_35                              eff=0.0219
# DITAU_35_25 OR DITAU_80_60                              eff=0.0219
# DITAU_35_25_J OR DITAU_40_35                            eff=0.0200
# DITAU_35_25_J OR DITAU_80_35                            eff=0.0172
# DITAU_35_25_J OR DITAU_80_60                            eff=0.0179
# DITAU_40_35 OR DITAU_80_35                              eff=0.0096
# DITAU_40_35 OR DITAU_80_60                              eff=0.0094
# DITAU_80_35 OR DITAU_80_60                              eff=0.0029
# J140_2J50 OR DITAU_35_25                                eff=0.0543
# J140_2J50 OR DITAU_35_25_J                              eff=0.0501
# J140_2J50 OR DITAU_40_35                                eff=0.0423
# J140_2J50 OR DITAU_80_35                                eff=0.0355
# J140_2J50 OR DITAU_80_60                                eff=0.0348
# J140_2J50 OR J150_2J55                                  eff=0.0336
# J140_2J50 OR J175_J60                                   eff=0.0367
# J150_2J55 OR DITAU_35_25                                eff=0.0490
# J150_2J55 OR DITAU_35_25_J                              eff=0.0448
# J150_2J55 OR DITAU_40_35                                eff=0.0370
# J150_2J55 OR DITAU_80_35                                eff=0.0301
# J150_2J55 OR DITAU_80_60                                eff=0.0294
# J150_2J55 OR J175_J60                                   eff=0.0313
# J175_J60 OR DITAU_35_25                                 eff=0.0331
# J175_J60 OR DITAU_35_25_J                               eff=0.0287
# J175_J60 OR DITAU_40_35                                 eff=0.0208
# J175_J60 OR DITAU_80_35                                 eff=0.0138
# J175_J60 OR DITAU_80_60                                 eff=0.0130
# J70 OR DITAU_35_25                                      eff=0.0678
# J70 OR DITAU_35_25_J                                    eff=0.0638
# J70 OR DITAU_40_35                                      eff=0.0561
# J70 OR DITAU_80_35                                      eff=0.0494
# J70 OR DITAU_80_60                                      eff=0.0487
# J70 OR J140_2J50                                        eff=0.0670
# J70 OR J150_2J55                                        eff=0.0630
# J70 OR J175_J60                                         eff=0.0554
# J70 OR J75                                              eff=0.0477
# J70 OR J_2J35                                           eff=0.0853
# J70 OR J_2J45                                           eff=0.0953
# J70 OR TAU+MET_PF                                       eff=0.0686
# J70 OR TAU+MET_TCP                                      eff=0.0702
# J70 OR TAU160                                           eff=0.0529
# J75 OR DITAU_35_25                                      eff=0.0566
# J75 OR DITAU_35_25_J                                    eff=0.0525
# J75 OR DITAU_40_35                                      eff=0.0448
# J75 OR DITAU_80_35                                      eff=0.0380
# J75 OR DITAU_80_60                                      eff=0.0373
# J75 OR J140_2J50                                        eff=0.0577
# J75 OR J150_2J55                                        eff=0.0534
# J75 OR J175_J60                                         eff=0.0442
# J75 OR J_2J35                                           eff=0.0768
# J75 OR J_2J45                                           eff=0.0875
# J75 OR TAU+MET_PF                                       eff=0.0578
# J75 OR TAU+MET_TCP                                      eff=0.0595
# J75 OR TAU160                                           eff=0.0416
# J_2J35 OR DITAU_35_25                                   eff=0.0712
# J_2J35 OR DITAU_35_25_J                                 eff=0.0674
# J_2J35 OR DITAU_40_35                                   eff=0.0601
# J_2J35 OR DITAU_80_35                                   eff=0.0537
# J_2J35 OR DITAU_80_60                                   eff=0.0531
# J_2J35 OR J140_2J50                                     eff=0.0718
# J_2J35 OR J150_2J55                                     eff=0.0685
# J_2J35 OR J175_J60                                      eff=0.0584
# J_2J35 OR J_2J45                                        eff=0.0787
# J_2J45 OR DITAU_35_25                                   eff=0.0840
# J_2J45 OR DITAU_35_25_J                                 eff=0.0801
# J_2J45 OR DITAU_40_35                                   eff=0.0726
# J_2J45 OR DITAU_80_35                                   eff=0.0662
# J_2J45 OR DITAU_80_60                                   eff=0.0655
# J_2J45 OR J140_2J50                                     eff=0.0784
# J_2J45 OR J150_2J55                                     eff=0.0759
# J_2J45 OR J175_J60                                      eff=0.0683
# PF_MET OR DITAU_35_25                                   eff=0.1653
# PF_MET OR DITAU_35_25_J                                 eff=0.1616
# PF_MET OR DITAU_40_35                                   eff=0.1542
# PF_MET OR DITAU_80_35                                   eff=0.1480
# PF_MET OR DITAU_80_60                                   eff=0.1472
# PF_MET OR J140_2J50                                     eff=0.1691
# PF_MET OR J150_2J55                                     eff=0.1651
# PF_MET OR J175_J60                                      eff=0.1543
# PF_MET OR J70                                           eff=0.1807
# PF_MET OR J75                                           eff=0.1718
# PF_MET OR J_2J35                                        eff=0.1883
# PF_MET OR J_2J45                                        eff=0.1987
# PF_MET OR TAU+MET_PF                                    eff=0.1530
# PF_MET OR TAU+MET_TCP                                   eff=0.1564
# PF_MET OR TAU160                                        eff=0.1512
# PF_MET OR TCP_MET                                       eff=0.1525
# TAU+MET_PF OR DITAU_35_25                               eff=0.0442
# TAU+MET_PF OR DITAU_35_25_J                             eff=0.0404
# TAU+MET_PF OR DITAU_40_35                               eff=0.0328
# TAU+MET_PF OR DITAU_80_35                               eff=0.0268
# TAU+MET_PF OR DITAU_80_60                               eff=0.0260
# TAU+MET_PF OR J140_2J50                                 eff=0.0559
# TAU+MET_PF OR J150_2J55                                 eff=0.0508
# TAU+MET_PF OR J175_J60                                  eff=0.0361
# TAU+MET_PF OR J_2J35                                    eff=0.0742
# TAU+MET_PF OR J_2J45                                    eff=0.0866
# TAU+MET_PF OR TAU+MET_TCP                               eff=0.0305
# TAU+MET_PF OR TAU160                                    eff=0.0297
# TAU+MET_TCP OR DITAU_35_25                              eff=0.0459
# TAU+MET_TCP OR DITAU_35_25_J                            eff=0.0423
# TAU+MET_TCP OR DITAU_40_35                              eff=0.0347
# TAU+MET_TCP OR DITAU_80_35                              eff=0.0287
# TAU+MET_TCP OR DITAU_80_60                              eff=0.0279
# TAU+MET_TCP OR J140_2J50                                eff=0.0574
# TAU+MET_TCP OR J150_2J55                                eff=0.0524
# TAU+MET_TCP OR J175_J60                                 eff=0.0379
# TAU+MET_TCP OR J_2J35                                   eff=0.0758
# TAU+MET_TCP OR J_2J45                                   eff=0.0882
# TAU+MET_TCP OR TAU160                                   eff=0.0313
# TAU160 OR DITAU_35_25                                   eff=0.0275
# TAU160 OR DITAU_35_25_J                                 eff=0.0236
# TAU160 OR DITAU_40_35                                   eff=0.0154
# TAU160 OR DITAU_80_35                                   eff=0.0088
# TAU160 OR DITAU_80_60                                   eff=0.0078
# TAU160 OR J140_2J50                                     eff=0.0393
# TAU160 OR J150_2J55                                     eff=0.0340
# TAU160 OR J175_J60                                      eff=0.0184
# TAU160 OR J_2J35                                        eff=0.0581
# TAU160 OR J_2J45                                        eff=0.0705
# TCP_MET OR DITAU_35_25                                  eff=0.1136
# TCP_MET OR DITAU_35_25_J                                eff=0.1097
# TCP_MET OR DITAU_40_35                                  eff=0.1020
# TCP_MET OR DITAU_80_35                                  eff=0.0955
# TCP_MET OR DITAU_80_60                                  eff=0.0948
# TCP_MET OR J140_2J50                                    eff=0.1190
# TCP_MET OR J150_2J55                                    eff=0.1146
# TCP_MET OR J175_J60                                     eff=0.1026
# TCP_MET OR J70                                          eff=0.1314
# TCP_MET OR J75                                          eff=0.1218
# TCP_MET OR J_2J35                                       eff=0.1389
# TCP_MET OR J_2J45                                       eff=0.1501
# TCP_MET OR TAU+MET_PF                                   eff=0.1069
# TCP_MET OR TAU+MET_TCP                                  eff=0.1082
# TCP_MET OR TAU160                                       eff=0.0989
#
# === Overall efficiencies (All AND combos) ===
# DITAU_35_25 AND DITAU_35_25_J                           eff=0.0157
# DITAU_35_25 AND DITAU_40_35                             eff=0.0085
# DITAU_35_25 AND DITAU_80_35                             eff=0.0020
# DITAU_35_25 AND DITAU_80_60                             eff=0.0012
# DITAU_35_25_J AND DITAU_40_35                           eff=0.0065
# DITAU_35_25_J AND DITAU_80_35                           eff=0.0022
# DITAU_35_25_J AND DITAU_80_60                           eff=0.0007
# DITAU_40_35 AND DITAU_80_35                             eff=0.0020
# DITAU_40_35 AND DITAU_80_60                             eff=0.0013
# DITAU_80_35 AND DITAU_80_60                             eff=0.0007
# J140_2J50 AND DITAU_35_25                               eff=0.0009
# J140_2J50 AND DITAU_35_25_J                             eff=0.0007
# J140_2J50 AND DITAU_40_35                               eff=0.0006
# J140_2J50 AND DITAU_80_35                               eff=0.0003
# J140_2J50 AND DITAU_80_60                               eff=0.0002
# J140_2J50 AND J150_2J55                                 eff=0.0282
# J140_2J50 AND J175_J60                                  eff=0.0086
# J150_2J55 AND DITAU_35_25                               eff=0.0008
# J150_2J55 AND DITAU_35_25_J                             eff=0.0006
# J150_2J55 AND DITAU_40_35                               eff=0.0005
# J150_2J55 AND DITAU_80_35                               eff=0.0002
# J150_2J55 AND DITAU_80_60                               eff=0.0002
# J150_2J55 AND J175_J60                                  eff=0.0086
# J175_J60 AND DITAU_35_25                                eff=0.0003
# J175_J60 AND DITAU_35_25_J                              eff=0.0002
# J175_J60 AND DITAU_40_35                                eff=0.0002
# J175_J60 AND DITAU_80_35                                eff=0.0001
# J175_J60 AND DITAU_80_60                                eff=0.0001
# J70 AND DITAU_35_25                                     eff=0.0016
# J70 AND DITAU_35_25_J                                   eff=0.0011
# J70 AND DITAU_40_35                                     eff=0.0009
# J70 AND DITAU_80_35                                     eff=0.0005
# J70 AND DITAU_80_60                                     eff=0.0004
# J70 AND J140_2J50                                       eff=0.0143
# J70 AND J150_2J55                                       eff=0.0129
# J70 AND J175_J60                                        eff=0.0041
# J70 AND J75                                             eff=0.0362
# J70 AND J_2J35                                          eff=0.0142
# J70 AND J_2J45                                          eff=0.0167
# J70 AND TAU+MET_PF                                      eff=0.0044
# J70 AND TAU+MET_TCP                                     eff=0.0046
# J70 AND TAU160                                          eff=0.0021
# J75 AND DITAU_35_25                                     eff=0.0012
# J75 AND DITAU_35_25_J                                   eff=0.0009
# J75 AND DITAU_40_35                                     eff=0.0007
# J75 AND DITAU_80_35                                     eff=0.0004
# J75 AND DITAU_80_60                                     eff=0.0003
# J75 AND J140_2J50                                       eff=0.0120
# J75 AND J150_2J55                                       eff=0.0110
# J75 AND J175_J60                                        eff=0.0036
# J75 AND J_2J35                                          eff=0.0111
# J75 AND J_2J45                                          eff=0.0129
# J75 AND TAU+MET_PF                                      eff=0.0036
# J75 AND TAU+MET_TCP                                     eff=0.0038
# J75 AND TAU160                                          eff=0.0018
# J_2J35 AND DITAU_35_25                                  eff=0.0022
# J_2J35 AND DITAU_35_25_J                                eff=0.0016
# J_2J35 AND DITAU_40_35                                  eff=0.0010
# J_2J35 AND DITAU_80_35                                  eff=0.0003
# J_2J35 AND DITAU_80_60                                  eff=0.0001
# J_2J35 AND J140_2J50                                    eff=0.0136
# J_2J35 AND J150_2J55                                    eff=0.0115
# J_2J35 AND J175_J60                                     eff=0.0051
# J_2J35 AND J_2J45                                       eff=0.0374
# J_2J45 AND DITAU_35_25                                  eff=0.0019
# J_2J45 AND DITAU_35_25_J                                eff=0.0014
# J_2J45 AND DITAU_40_35                                  eff=0.0009
# J_2J45 AND DITAU_80_35                                  eff=0.0003
# J_2J45 AND DITAU_80_60                                  eff=0.0002
# J_2J45 AND J140_2J50                                    eff=0.0194
# J_2J45 AND J150_2J55                                    eff=0.0165
# J_2J45 AND J175_J60                                     eff=0.0076
# PF_MET AND DITAU_35_25                                  eff=0.0027
# PF_MET AND DITAU_35_25_J                                eff=0.0020
# PF_MET AND DITAU_40_35                                  eff=0.0015
# PF_MET AND DITAU_80_35                                  eff=0.0006
# PF_MET AND DITAU_80_60                                  eff=0.0006
# PF_MET AND J140_2J50                                    eff=0.0108
# PF_MET AND J150_2J55                                    eff=0.0095
# PF_MET AND J175_J60                                     eff=0.0038
# PF_MET AND J70                                          eff=0.0134
# PF_MET AND J75                                          eff=0.0108
# PF_MET AND J_2J35                                       eff=0.0098
# PF_MET AND J_2J45                                       eff=0.0119
# PF_MET AND TAU+MET_PF                                   eff=0.0185
# PF_MET AND TAU+MET_TCP                                  eff=0.0172
# PF_MET AND TAU160                                       eff=0.0024
# PF_MET AND TCP_MET                                      eff=0.0877
# TAU+MET_PF AND DITAU_35_25                              eff=0.0027
# TAU+MET_PF AND DITAU_35_25_J                            eff=0.0020
# TAU+MET_PF AND DITAU_40_35                              eff=0.0018
# TAU+MET_PF AND DITAU_80_35                              eff=0.0006
# TAU+MET_PF AND DITAU_80_60                              eff=0.0006
# TAU+MET_PF AND J140_2J50                                eff=0.0029
# TAU+MET_PF AND J150_2J55                                eff=0.0026
# TAU+MET_PF AND J175_J60                                 eff=0.0008
# TAU+MET_PF AND J_2J35                                   eff=0.0028
# TAU+MET_PF AND J_2J45                                   eff=0.0029
# TAU+MET_PF AND TAU+MET_TCP                              eff=0.0219
# TAU+MET_PF AND TAU160                                   eff=0.0027
# TAU+MET_TCP AND DITAU_35_25                             eff=0.0029
# TAU+MET_TCP AND DITAU_35_25_J                           eff=0.0021
# TAU+MET_TCP AND DITAU_40_35                             eff=0.0018
# TAU+MET_TCP AND DITAU_80_35                             eff=0.0007
# TAU+MET_TCP AND DITAU_80_60                             eff=0.0006
# TAU+MET_TCP AND J140_2J50                               eff=0.0033
# TAU+MET_TCP AND J150_2J55                               eff=0.0029
# TAU+MET_TCP AND J175_J60                                eff=0.0009
# TAU+MET_TCP AND J_2J35                                  eff=0.0031
# TAU+MET_TCP AND J_2J45                                  eff=0.0032
# TAU+MET_TCP AND TAU160                                  eff=0.0031
# TAU160 AND DITAU_35_25                                  eff=0.0014
# TAU160 AND DITAU_35_25_J                                eff=0.0008
# TAU160 AND DITAU_40_35                                  eff=0.0011
# TAU160 AND DITAU_80_35                                  eff=0.0006
# TAU160 AND DITAU_80_60                                  eff=0.0008
# TAU160 AND J140_2J50                                    eff=0.0015
# TAU160 AND J150_2J55                                    eff=0.0014
# TAU160 AND J175_J60                                     eff=0.0005
# TAU160 AND J_2J35                                       eff=0.0009
# TAU160 AND J_2J45                                       eff=0.0009
# TCP_MET AND DITAU_35_25                                 eff=0.0019
# TCP_MET AND DITAU_35_25_J                               eff=0.0013
# TCP_MET AND DITAU_40_35                                 eff=0.0012
# TCP_MET AND DITAU_80_35                                 eff=0.0005
# TCP_MET AND DITAU_80_60                                 eff=0.0005
# TCP_MET AND J140_2J50                                   eff=0.0084
# TCP_MET AND J150_2J55                                   eff=0.0074
# TCP_MET AND J175_J60                                    eff=0.0029
# TCP_MET AND J70                                         eff=0.0101
# TCP_MET AND J75                                         eff=0.0082
# TCP_MET AND J_2J35                                      eff=0.0067
# TCP_MET AND J_2J45                                      eff=0.0080
# TCP_MET AND TAU+MET_PF                                  eff=0.0122
# TCP_MET AND TAU+MET_TCP                                 eff=0.0128
# TCP_MET AND TAU160                                      eff=0.0021
#
# === Specific combos ===
# PF_MET OR TAU+MET_PF: 0.1530493291884817
# J70 OR TAU+MET_PF: 0.06856389070680628
# PF_MET OR J70: 0.18067940117801048

# %%
from itertools import combinations

print("\n=== Overlap counts (A only / B only / both / neither) ===")
for a, b in combinations(base.keys(), 2):
    A = base[a]
    B = base[b]
    a_only = (A & ~B).sum()
    b_only = (~A & B).sum()
    both   = (A & B).sum()
    neither= (~A & ~B).sum()

    # usefl fractions (avoid divide-by-zero)
    frac_a_not_b = (a_only / A.sum()) if A.sum() > 0 else np.nan
    frac_b_not_a = (b_only / B.sum()) if B.sum() > 0 else np.nan

    print(f"{a:14s} vs {b:14s} | "
          f"Aonly={a_only:7d} Bonly={b_only:7d} both={both:7d} neither={neither:7d} | "
          f"frac(A not B)={frac_a_not_b:.3f}  frac(B not A)={frac_b_not_a:.3f}")
# Out:
# === Overlap counts (A only / B only / both / neither) ===
# PF_MET         vs TCP_MET        | Aonly=   5733 Bonly=    595 both=   8581 neither=  82883 | frac(A not B)=0.401  frac(B not A)=0.065
# PF_MET         vs J70            | Aonly=  13002 Bonly=   3355 both=   1312 neither=  80123 | frac(A not B)=0.908  frac(B not A)=0.719
# PF_MET         vs J75            | Aonly=  13262 Bonly=   2486 both=   1052 neither=  80992 | frac(A not B)=0.927  frac(B not A)=0.703
# PF_MET         vs TAU+MET_PF     | Aonly=  12501 Bonly=    653 both=   1813 neither=  82825 | frac(A not B)=0.873  frac(B not A)=0.265
# PF_MET         vs TAU+MET_TCP    | Aonly=  12636 Bonly=    977 both=   1678 neither=  82501 | frac(A not B)=0.883  frac(B not A)=0.368
# PF_MET         vs TAU160         | Aonly=  14083 Bonly=    474 both=    231 neither=  83004 | frac(A not B)=0.984  frac(B not A)=0.672
# PF_MET         vs J_2J35         | Aonly=  13352 Bonly=   4103 both=    962 neither=  79375 | frac(A not B)=0.933  frac(B not A)=0.810
# PF_MET         vs J_2J45         | Aonly=  13146 Bonly=   5116 both=   1168 neither=  78362 | frac(A not B)=0.918  frac(B not A)=0.814
# PF_MET         vs J140_2J50      | Aonly=  13258 Bonly=   2227 both=   1056 neither=  81251 | frac(A not B)=0.926  frac(B not A)=0.678
# PF_MET         vs J150_2J55      | Aonly=  13389 Bonly=   1829 both=    925 neither=  81649 | frac(A not B)=0.935  frac(B not A)=0.664
# PF_MET         vs J175_J60       | Aonly=  13944 Bonly=    775 both=    370 neither=  82703 | frac(A not B)=0.974  frac(B not A)=0.677
# PF_MET         vs DITAU_35_25    | Aonly=  14046 Bonly=   1850 both=    268 neither=  81628 | frac(A not B)=0.981  frac(B not A)=0.873
# PF_MET         vs DITAU_35_25_J  | Aonly=  14116 Bonly=   1485 both=    198 neither=  81993 | frac(A not B)=0.986  frac(B not A)=0.882
# PF_MET         vs DITAU_40_35    | Aonly=  14168 Bonly=    764 both=    146 neither=  82714 | frac(A not B)=0.990  frac(B not A)=0.840
# PF_MET         vs DITAU_80_35    | Aonly=  14260 Bonly=    162 both=     54 neither=  83316 | frac(A not B)=0.996  frac(B not A)=0.750
# PF_MET         vs DITAU_80_60    | Aonly=  14260 Bonly=     84 both=     54 neither=  83394 | frac(A not B)=0.996  frac(B not A)=0.609
# TCP_MET        vs J70            | Aonly=   8187 Bonly=   3678 both=    989 neither=  84938 | frac(A not B)=0.892  frac(B not A)=0.788
# TCP_MET        vs J75            | Aonly=   8370 Bonly=   2732 both=    806 neither=  85884 | frac(A not B)=0.912  frac(B not A)=0.772
# TCP_MET        vs TAU+MET_PF     | Aonly=   7984 Bonly=   1274 both=   1192 neither=  87342 | frac(A not B)=0.870  frac(B not A)=0.517
# TCP_MET        vs TAU+MET_TCP    | Aonly=   7929 Bonly=   1408 both=   1247 neither=  87208 | frac(A not B)=0.864  frac(B not A)=0.530
# TCP_MET        vs TAU160         | Aonly=   8968 Bonly=    497 both=    208 neither=  88119 | frac(A not B)=0.977  frac(B not A)=0.705
# TCP_MET        vs J_2J35         | Aonly=   8520 Bonly=   4409 both=    656 neither=  84207 | frac(A not B)=0.929  frac(B not A)=0.870
# TCP_MET        vs J_2J45         | Aonly=   8393 Bonly=   5501 both=    783 neither=  83115 | frac(A not B)=0.915  frac(B not A)=0.875
# TCP_MET        vs J140_2J50      | Aonly=   8356 Bonly=   2463 both=    820 neither=  86153 | frac(A not B)=0.911  frac(B not A)=0.750
# TCP_MET        vs J150_2J55      | Aonly=   8453 Bonly=   2031 both=    723 neither=  86585 | frac(A not B)=0.921  frac(B not A)=0.737
# TCP_MET        vs J175_J60       | Aonly=   8893 Bonly=    862 both=    283 neither=  87754 | frac(A not B)=0.969  frac(B not A)=0.753
# TCP_MET        vs DITAU_35_25    | Aonly=   8994 Bonly=   1936 both=    182 neither=  86680 | frac(A not B)=0.980  frac(B not A)=0.914
# TCP_MET        vs DITAU_35_25_J  | Aonly=   9044 Bonly=   1551 both=    132 neither=  87065 | frac(A not B)=0.986  frac(B not A)=0.922
# TCP_MET        vs DITAU_40_35    | Aonly=   9063 Bonly=    797 both=    113 neither=  87819 | frac(A not B)=0.988  frac(B not A)=0.876
# TCP_MET        vs DITAU_80_35    | Aonly=   9127 Bonly=    167 both=     49 neither=  88449 | frac(A not B)=0.995  frac(B not A)=0.773
# TCP_MET        vs DITAU_80_60    | Aonly=   9128 Bonly=     90 both=     48 neither=  88526 | frac(A not B)=0.995  frac(B not A)=0.652
# J70            vs J75            | Aonly=   1129 Bonly=      0 both=   3538 neither=  93125 | frac(A not B)=0.242  frac(B not A)=0.000
# J70            vs TAU+MET_PF     | Aonly=   4239 Bonly=   2038 both=    428 neither=  91087 | frac(A not B)=0.908  frac(B not A)=0.826
# J70            vs TAU+MET_TCP    | Aonly=   4214 Bonly=   2202 both=    453 neither=  90923 | frac(A not B)=0.903  frac(B not A)=0.829
# J70            vs TAU160         | Aonly=   4466 Bonly=    504 both=    201 neither=  92621 | frac(A not B)=0.957  frac(B not A)=0.715
# J70            vs J_2J35         | Aonly=   3281 Bonly=   3679 both=   1386 neither=  89446 | frac(A not B)=0.703  frac(B not A)=0.726
# J70            vs J_2J45         | Aonly=   3036 Bonly=   4653 both=   1631 neither=  88472 | frac(A not B)=0.651  frac(B not A)=0.740
# J70            vs J140_2J50      | Aonly=   3267 Bonly=   1883 both=   1400 neither=  91242 | frac(A not B)=0.700  frac(B not A)=0.574
# J70            vs J150_2J55      | Aonly=   3406 Bonly=   1493 both=   1261 neither=  91632 | frac(A not B)=0.730  frac(B not A)=0.542
# J70            vs J175_J60       | Aonly=   4270 Bonly=    748 both=    397 neither=  92377 | frac(A not B)=0.915  frac(B not A)=0.653
# J70            vs DITAU_35_25    | Aonly=   4511 Bonly=   1962 both=    156 neither=  91163 | frac(A not B)=0.967  frac(B not A)=0.926
# J70            vs DITAU_35_25_J  | Aonly=   4558 Bonly=   1574 both=    109 neither=  91551 | frac(A not B)=0.977  frac(B not A)=0.935
# J70            vs DITAU_40_35    | Aonly=   4575 Bonly=    818 both=     92 neither=  92307 | frac(A not B)=0.980  frac(B not A)=0.899
# J70            vs DITAU_80_35    | Aonly=   4617 Bonly=    166 both=     50 neither=  92959 | frac(A not B)=0.989  frac(B not A)=0.769
# J70            vs DITAU_80_60    | Aonly=   4628 Bonly=     99 both=     39 neither=  93026 | frac(A not B)=0.992  frac(B not A)=0.717
# J75            vs TAU+MET_PF     | Aonly=   3185 Bonly=   2113 both=    353 neither=  92141 | frac(A not B)=0.900  frac(B not A)=0.857
# J75            vs TAU+MET_TCP    | Aonly=   3165 Bonly=   2282 both=    373 neither=  91972 | frac(A not B)=0.895  frac(B not A)=0.860
# J75            vs TAU160         | Aonly=   3359 Bonly=    526 both=    179 neither=  93728 | frac(A not B)=0.949  frac(B not A)=0.746
# J75            vs J_2J35         | Aonly=   2448 Bonly=   3975 both=   1090 neither=  90279 | frac(A not B)=0.692  frac(B not A)=0.785
# J75            vs J_2J45         | Aonly=   2276 Bonly=   5022 both=   1262 neither=  89232 | frac(A not B)=0.643  frac(B not A)=0.799
# J75            vs J140_2J50      | Aonly=   2361 Bonly=   2106 both=   1177 neither=  92148 | frac(A not B)=0.667  frac(B not A)=0.641
# J75            vs J150_2J55      | Aonly=   2465 Bonly=   1681 both=   1073 neither=  92573 | frac(A not B)=0.697  frac(B not A)=0.610
# J75            vs J175_J60       | Aonly=   3182 Bonly=    789 both=    356 neither=  93465 | frac(A not B)=0.899  frac(B not A)=0.689
# J75            vs DITAU_35_25    | Aonly=   3421 Bonly=   2001 both=    117 neither=  92253 | frac(A not B)=0.967  frac(B not A)=0.945
# J75            vs DITAU_35_25_J  | Aonly=   3454 Bonly=   1599 both=     84 neither=  92655 | frac(A not B)=0.976  frac(B not A)=0.950
# J75            vs DITAU_40_35    | Aonly=   3470 Bonly=    842 both=     68 neither=  93412 | frac(A not B)=0.981  frac(B not A)=0.925
# J75            vs DITAU_80_35    | Aonly=   3498 Bonly=    176 both=     40 neither=  94078 | frac(A not B)=0.989  frac(B not A)=0.815
# J75            vs DITAU_80_60    | Aonly=   3505 Bonly=    105 both=     33 neither=  94149 | frac(A not B)=0.991  frac(B not A)=0.761
# TAU+MET_PF     vs TAU+MET_TCP    | Aonly=    329 Bonly=    518 both=   2137 neither=  94808 | frac(A not B)=0.133  frac(B not A)=0.195
# TAU+MET_PF     vs TAU160         | Aonly=   2199 Bonly=    438 both=    267 neither=  94888 | frac(A not B)=0.892  frac(B not A)=0.621
# TAU+MET_PF     vs J_2J35         | Aonly=   2194 Bonly=   4793 both=    272 neither=  90533 | frac(A not B)=0.890  frac(B not A)=0.946
# TAU+MET_PF     vs J_2J45         | Aonly=   2184 Bonly=   6002 both=    282 neither=  89324 | frac(A not B)=0.886  frac(B not A)=0.955
# TAU+MET_PF     vs J140_2J50      | Aonly=   2182 Bonly=   2999 both=    284 neither=  92327 | frac(A not B)=0.885  frac(B not A)=0.913
# TAU+MET_PF     vs J150_2J55      | Aonly=   2215 Bonly=   2503 both=    251 neither=  92823 | frac(A not B)=0.898  frac(B not A)=0.909
# TAU+MET_PF     vs J175_J60       | Aonly=   2384 Bonly=   1063 both=     82 neither=  94263 | frac(A not B)=0.967  frac(B not A)=0.928
# TAU+MET_PF     vs DITAU_35_25    | Aonly=   2200 Bonly=   1852 both=    266 neither=  93474 | frac(A not B)=0.892  frac(B not A)=0.874
# TAU+MET_PF     vs DITAU_35_25_J  | Aonly=   2269 Bonly=   1486 both=    197 neither=  93840 | frac(A not B)=0.920  frac(B not A)=0.883
# TAU+MET_PF     vs DITAU_40_35    | Aonly=   2293 Bonly=    737 both=    173 neither=  94589 | frac(A not B)=0.930  frac(B not A)=0.810
# TAU+MET_PF     vs DITAU_80_35    | Aonly=   2404 Bonly=    154 both=     62 neither=  95172 | frac(A not B)=0.975  frac(B not A)=0.713
# TAU+MET_PF     vs DITAU_80_60    | Aonly=   2406 Bonly=     78 both=     60 neither=  95248 | frac(A not B)=0.976  frac(B not A)=0.565
# TAU+MET_TCP    vs TAU160         | Aonly=   2354 Bonly=    404 both=    301 neither=  94733 | frac(A not B)=0.887  frac(B not A)=0.573
# TAU+MET_TCP    vs J_2J35         | Aonly=   2349 Bonly=   4759 both=    306 neither=  90378 | frac(A not B)=0.885  frac(B not A)=0.940
# TAU+MET_TCP    vs J_2J45         | Aonly=   2340 Bonly=   5969 both=    315 neither=  89168 | frac(A not B)=0.881  frac(B not A)=0.950
# TAU+MET_TCP    vs J140_2J50      | Aonly=   2335 Bonly=   2963 both=    320 neither=  92174 | frac(A not B)=0.879  frac(B not A)=0.903
# TAU+MET_TCP    vs J150_2J55      | Aonly=   2370 Bonly=   2469 both=    285 neither=  92668 | frac(A not B)=0.893  frac(B not A)=0.897
# TAU+MET_TCP    vs J175_J60       | Aonly=   2565 Bonly=   1055 both=     90 neither=  94082 | frac(A not B)=0.966  frac(B not A)=0.921
# TAU+MET_TCP    vs DITAU_35_25    | Aonly=   2374 Bonly=   1837 both=    281 neither=  93300 | frac(A not B)=0.894  frac(B not A)=0.867
# TAU+MET_TCP    vs DITAU_35_25_J  | Aonly=   2449 Bonly=   1477 both=    206 neither=  93660 | frac(A not B)=0.922  frac(B not A)=0.878
# TAU+MET_TCP    vs DITAU_40_35    | Aonly=   2480 Bonly=    735 both=    175 neither=  94402 | frac(A not B)=0.934  frac(B not A)=0.808
# TAU+MET_TCP    vs DITAU_80_35    | Aonly=   2590 Bonly=    151 both=     65 neither=  94986 | frac(A not B)=0.976  frac(B not A)=0.699
# TAU+MET_TCP    vs DITAU_80_60    | Aonly=   2595 Bonly=     78 both=     60 neither=  95059 | frac(A not B)=0.977  frac(B not A)=0.565
# TAU160         vs J_2J35         | Aonly=    616 Bonly=   4976 both=     89 neither=  92111 | frac(A not B)=0.874  frac(B not A)=0.982
# TAU160         vs J_2J45         | Aonly=    613 Bonly=   6192 both=     92 neither=  90895 | frac(A not B)=0.870  frac(B not A)=0.985
# TAU160         vs J140_2J50      | Aonly=    561 Bonly=   3139 both=    144 neither=  93948 | frac(A not B)=0.796  frac(B not A)=0.956
# TAU160         vs J150_2J55      | Aonly=    569 Bonly=   2618 both=    136 neither=  94469 | frac(A not B)=0.807  frac(B not A)=0.951
# TAU160         vs J175_J60       | Aonly=    656 Bonly=   1096 both=     49 neither=  95991 | frac(A not B)=0.930  frac(B not A)=0.957
# TAU160         vs DITAU_35_25    | Aonly=    569 Bonly=   1982 both=    136 neither=  95105 | frac(A not B)=0.807  frac(B not A)=0.936
# TAU160         vs DITAU_35_25_J  | Aonly=    624 Bonly=   1602 both=     81 neither=  95485 | frac(A not B)=0.885  frac(B not A)=0.952
# TAU160         vs DITAU_40_35    | Aonly=    597 Bonly=    802 both=    108 neither=  96285 | frac(A not B)=0.847  frac(B not A)=0.881
# TAU160         vs DITAU_80_35    | Aonly=    642 Bonly=    153 both=     63 neither=  96934 | frac(A not B)=0.911  frac(B not A)=0.708
# TAU160         vs DITAU_80_60    | Aonly=    626 Bonly=     59 both=     79 neither=  97028 | frac(A not B)=0.888  frac(B not A)=0.428
# J_2J35         vs J_2J45         | Aonly=   1410 Bonly=   2629 both=   3655 neither=  90098 | frac(A not B)=0.278  frac(B not A)=0.418
# J_2J35         vs J140_2J50      | Aonly=   3737 Bonly=   1955 both=   1328 neither=  90772 | frac(A not B)=0.738  frac(B not A)=0.595
# J_2J35         vs J150_2J55      | Aonly=   3941 Bonly=   1630 both=   1124 neither=  91097 | frac(A not B)=0.778  frac(B not A)=0.592
# J_2J35         vs J175_J60       | Aonly=   4563 Bonly=    643 both=    502 neither=  92084 | frac(A not B)=0.901  frac(B not A)=0.562
# J_2J35         vs DITAU_35_25    | Aonly=   4848 Bonly=   1901 both=    217 neither=  90826 | frac(A not B)=0.957  frac(B not A)=0.898
# J_2J35         vs DITAU_35_25_J  | Aonly=   4906 Bonly=   1524 both=    159 neither=  91203 | frac(A not B)=0.969  frac(B not A)=0.906
# J_2J35         vs DITAU_40_35    | Aonly=   4970 Bonly=    815 both=     95 neither=  91912 | frac(A not B)=0.981  frac(B not A)=0.896
# J_2J35         vs DITAU_80_35    | Aonly=   5038 Bonly=    189 both=     27 neither=  92538 | frac(A not B)=0.995  frac(B not A)=0.875
# J_2J35         vs DITAU_80_60    | Aonly=   5051 Bonly=    124 both=     14 neither=  92603 | frac(A not B)=0.997  frac(B not A)=0.899
# J_2J45         vs J140_2J50      | Aonly=   4382 Bonly=   1381 both=   1902 neither=  90127 | frac(A not B)=0.697  frac(B not A)=0.421
# J_2J45         vs J150_2J55      | Aonly=   4671 Bonly=   1141 both=   1613 neither=  90367 | frac(A not B)=0.743  frac(B not A)=0.414
# J_2J45         vs J175_J60       | Aonly=   5538 Bonly=    399 both=    746 neither=  91109 | frac(A not B)=0.881  frac(B not A)=0.348
# J_2J45         vs DITAU_35_25    | Aonly=   6100 Bonly=   1934 both=    184 neither=  89574 | frac(A not B)=0.971  frac(B not A)=0.913
# J_2J45         vs DITAU_35_25_J  | Aonly=   6148 Bonly=   1547 both=    136 neither=  89961 | frac(A not B)=0.978  frac(B not A)=0.919
# J_2J45         vs DITAU_40_35    | Aonly=   6192 Bonly=    818 both=     92 neither=  90690 | frac(A not B)=0.985  frac(B not A)=0.899
# J_2J45         vs DITAU_80_35    | Aonly=   6254 Bonly=    186 both=     30 neither=  91322 | frac(A not B)=0.995  frac(B not A)=0.861
# J_2J45         vs DITAU_80_60    | Aonly=   6269 Bonly=    123 both=     15 neither=  91385 | frac(A not B)=0.998  frac(B not A)=0.891
# J140_2J50      vs J150_2J55      | Aonly=    529 Bonly=      0 both=   2754 neither=  94509 | frac(A not B)=0.161  frac(B not A)=0.000
# J140_2J50      vs J175_J60       | Aonly=   2443 Bonly=    305 both=    840 neither=  94204 | frac(A not B)=0.744  frac(B not A)=0.266
# J140_2J50      vs DITAU_35_25    | Aonly=   3192 Bonly=   2027 both=     91 neither=  92482 | frac(A not B)=0.972  frac(B not A)=0.957
# J140_2J50      vs DITAU_35_25_J  | Aonly=   3217 Bonly=   1617 both=     66 neither=  92892 | frac(A not B)=0.980  frac(B not A)=0.961
# J140_2J50      vs DITAU_40_35    | Aonly=   3228 Bonly=    855 both=     55 neither=  93654 | frac(A not B)=0.983  frac(B not A)=0.940
# J140_2J50      vs DITAU_80_35    | Aonly=   3258 Bonly=    191 both=     25 neither=  94318 | frac(A not B)=0.992  frac(B not A)=0.884
# J140_2J50      vs DITAU_80_60    | Aonly=   3262 Bonly=    117 both=     21 neither=  94392 | frac(A not B)=0.994  frac(B not A)=0.848
# J150_2J55      vs J175_J60       | Aonly=   1917 Bonly=    308 both=    837 neither=  94730 | frac(A not B)=0.696  frac(B not A)=0.269
# J150_2J55      vs DITAU_35_25    | Aonly=   2674 Bonly=   2038 both=     80 neither=  93000 | frac(A not B)=0.971  frac(B not A)=0.962
# J150_2J55      vs DITAU_35_25_J  | Aonly=   2697 Bonly=   1626 both=     57 neither=  93412 | frac(A not B)=0.979  frac(B not A)=0.966
# J150_2J55      vs DITAU_40_35    | Aonly=   2706 Bonly=    862 both=     48 neither=  94176 | frac(A not B)=0.983  frac(B not A)=0.947
# J150_2J55      vs DITAU_80_35    | Aonly=   2731 Bonly=    193 both=     23 neither=  94845 | frac(A not B)=0.992  frac(B not A)=0.894
# J150_2J55      vs DITAU_80_60    | Aonly=   2734 Bonly=    118 both=     20 neither=  94920 | frac(A not B)=0.993  frac(B not A)=0.855
# J175_J60       vs DITAU_35_25    | Aonly=   1118 Bonly=   2091 both=     27 neither=  94556 | frac(A not B)=0.976  frac(B not A)=0.987
# J175_J60       vs DITAU_35_25_J  | Aonly=   1128 Bonly=   1666 both=     17 neither=  94981 | frac(A not B)=0.985  frac(B not A)=0.990
# J175_J60       vs DITAU_40_35    | Aonly=   1123 Bonly=    888 both=     22 neither=  95759 | frac(A not B)=0.981  frac(B not A)=0.976
# J175_J60       vs DITAU_80_35    | Aonly=   1137 Bonly=    208 both=      8 neither=  96439 | frac(A not B)=0.993  frac(B not A)=0.963
# J175_J60       vs DITAU_80_60    | Aonly=   1134 Bonly=    127 both=     11 neither=  96520 | frac(A not B)=0.990  frac(B not A)=0.920
# DITAU_35_25    vs DITAU_35_25_J  | Aonly=    586 Bonly=    151 both=   1532 neither=  95523 | frac(A not B)=0.277  frac(B not A)=0.090
# DITAU_35_25    vs DITAU_40_35    | Aonly=   1284 Bonly=     76 both=    834 neither=  95598 | frac(A not B)=0.606  frac(B not A)=0.084
# DITAU_35_25    vs DITAU_80_35    | Aonly=   1924 Bonly=     22 both=    194 neither=  95652 | frac(A not B)=0.908  frac(B not A)=0.102
# DITAU_35_25    vs DITAU_80_60    | Aonly=   1999 Bonly=     19 both=    119 neither=  95655 | frac(A not B)=0.944  frac(B not A)=0.138
# DITAU_35_25_J  vs DITAU_40_35    | Aonly=   1047 Bonly=    274 both=    636 neither=  95835 | frac(A not B)=0.622  frac(B not A)=0.301
# DITAU_35_25_J  vs DITAU_80_35    | Aonly=   1469 Bonly=      2 both=    214 neither=  96107 | frac(A not B)=0.873  frac(B not A)=0.009
# DITAU_35_25_J  vs DITAU_80_60    | Aonly=   1612 Bonly=     67 both=     71 neither=  96042 | frac(A not B)=0.958  frac(B not A)=0.486
# DITAU_40_35    vs DITAU_80_35    | Aonly=    719 Bonly=     25 both=    191 neither=  96857 | frac(A not B)=0.790  frac(B not A)=0.116
# DITAU_40_35    vs DITAU_80_60    | Aonly=    782 Bonly=     10 both=    128 neither=  96872 | frac(A not B)=0.859  frac(B not A)=0.072
# DITAU_80_35    vs DITAU_80_60    | Aonly=    146 Bonly=     68 both=     70 neither=  97508 | frac(A not B)=0.676  frac(B not A)=0.493

# %%
# binomial efficiency + 1-sigma uncertainty ----
def eff_err(passed, total):
    if total == 0:
        return np.nan, np.nan
    eff = passed / total
    err = np.sqrt(eff * (1 - eff) / total)
    return eff, err

bins = np.linspace(0, 350, 30)
centers = 0.5 * (bins[:-1] + bins[1:])

# choose a focused set to plot + quantify
focus = {
    "PF_MET": base["PF_MET"],
    "TCP_MET": base["TCP_MET"],
    "J70": base["J70"],
    "TAU+MET_PF": base["TAU+MET_PF"],
    "TAU+MET_TCP": base["TAU+MET_TCP"],
    "PF_MET OR J70": OR["PF_MET OR J70"],
    "PF_MET OR TAU+MET_PF": OR["PF_MET OR TAU+MET_PF"],
    "J70 OR TAU+MET_PF": OR["J70 OR TAU+MET_PF"],
    "PF_MET AND TAU+MET_PF": AND["PF_MET AND TAU+MET_PF"],
    "TAU160": base["TAU160"],
    "PF_MET OR TAU160": OR["PF_MET OR TAU160"],
    "J70 OR TAU160": OR["J70 OR TAU160"],
    # new triggers worth comparing on the turn-on plot
    "J_2J45": base["J_2J45"],
    "PF_MET OR J_2J45": OR["PF_MET OR J_2J45"],
    "DITAU_35_25": base["DITAU_35_25"],
    "PF_MET OR DITAU_35_25": OR["PF_MET OR DITAU_35_25"],
}

# storage
Nbin = []
out = {k: {"eff": [], "err": []} for k in focus.keys()}

for i in range(len(bins) - 1):
    lo, hi = bins[i], bins[i+1]
    sel = (offline_met_gev >= lo) & (offline_met_gev < hi)
    total = sel.sum()
    Nbin.append(total)

    for name, mask in focus.items():
        if total < 50:
            out[name]["eff"].append(np.nan)
            out[name]["err"].append(np.nan)
        else:
            passed = (mask & sel).sum()
            e, s = eff_err(passed, total)
            out[name]["eff"].append(e)
            out[name]["err"].append(s)

# plot with error bars
plt.figure(figsize=(10, 6))
for name in ["PF_MET", "TCP_MET", "J70", "TAU+MET_PF", "TAU+MET_TCP",
             "TAU160",
             "PF_MET OR J70", "PF_MET OR TAU+MET_PF", "J70 OR TAU+MET_PF",
             "PF_MET OR TAU160", "J70 OR TAU160",
             "J_2J45", "PF_MET OR J_2J45",
             "DITAU_35_25", "PF_MET OR DITAU_35_25"]:
    plt.errorbar(
        centers,
        out[name]["eff"],
        yerr=out[name]["err"],
        fmt="o",
        label=name
    )

plt.xlabel("Offline MET [GeV]")
plt.ylabel("Efficiency")
plt.ylim(0, 1.05)
plt.legend(fontsize=8, ncol=2)
plt.title(f"Trigger turn-on vs offline MET — {sample_label}")
plt.show()

# quantified table: 100–200 GeV
print("\n=== Per-bin quantification (100–200 GeV offline MET) ===")
print("bin[GeV]      N    PF_MET        TAU+MET_PF    PF_MET OR TAU+MET_PF  J70 OR TAU+MET_PF  PF_MET OR J_2J45  PF_MET OR DITAU_35_25")
print("-"*150)
for i in range(len(bins)-1):
    lo, hi = bins[i], bins[i+1]
    if lo < 100 or hi > 200:
        continue
    total = Nbin[i]
    if total < 50:
        continue

    def fmt(name):
        e = out[name]["eff"][i]
        s = out[name]["err"][i]
        return f"{e:6.3f}±{s:5.3f}"

    print(f"[{lo:5.1f},{hi:5.1f})  {total:5d}  "
          f"{fmt('PF_MET'):>12s}  "
          f"{fmt('TAU+MET_PF'):>12s}  "
          f"{fmt('PF_MET OR TAU+MET_PF'):>20s}  "
          f"{fmt('J70 OR TAU+MET_PF'):>17s}  "
          f"{fmt('PF_MET OR J_2J45'):>16s}  "
          f"{fmt('PF_MET OR DITAU_35_25'):>20s}")
# Out:
# === Per-bin quantification (100–200 GeV offline MET) ===
# bin[GeV]      N    PF_MET        TAU+MET_PF    PF_MET OR TAU+MET_PF  J70 OR TAU+MET_PF  PF_MET OR J_2J45  PF_MET OR DITAU_35_25
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [108.6,120.7)   4444   0.328±0.007   0.057±0.003           0.347±0.007        0.107±0.005       0.370±0.007           0.342±0.007
# [120.7,132.8)   3328   0.457±0.009   0.067±0.004           0.480±0.009        0.124±0.006       0.493±0.009           0.465±0.009
# [132.8,144.8)   2550   0.592±0.010   0.089±0.006           0.611±0.010        0.142±0.007       0.622±0.010           0.600±0.010
# [144.8,156.9)   1904   0.699±0.011   0.096±0.007           0.713±0.010        0.157±0.008       0.727±0.010           0.705±0.010
# [156.9,169.0)   1395   0.805±0.011   0.113±0.008           0.815±0.010        0.184±0.010       0.825±0.010           0.809±0.011
# [169.0,181.0)   1053   0.858±0.011   0.120±0.010           0.868±0.010        0.190±0.012       0.871±0.010           0.861±0.011
# [181.0,193.1)    808   0.920±0.010   0.125±0.012           0.922±0.009        0.223±0.015       0.926±0.009           0.922±0.009

# %%
# tau trigger efficiency vs leading tau pt
lead_tau_pt = []
for i in range(len(df)):
    pts = df["tau_pt_NOSYS"][i]   # list of tau pts (MeV)
    if len(pts) > 0:
        lead_tau_pt.append(max(pts) / 1000.0)   # GeV
    else:
        lead_tau_pt.append(np.nan)

lead_tau_pt = np.array(lead_tau_pt)
print("lead tau pt min/max (GeV):", np.nanmin(lead_tau_pt), np.nanmax(lead_tau_pt))

bins_tau = np.linspace(0, 300, 31)
centers = []
eff_tau_pf_pt = []
eff_tau_tcp_pt = []
eff_tau160_pt = []

for i in range(len(bins_tau) - 1):
    lo = bins_tau[i]
    hi = bins_tau[i + 1]
    sel = (lead_tau_pt >= lo) & (lead_tau_pt < hi) & np.isfinite(lead_tau_pt)
    centers.append((lo + hi) / 2)

    if sel.sum() < 20:    # smaller cutoff so don't get a billion NaNs
        eff_tau_pf_pt.append(np.nan)
        eff_tau_tcp_pt.append(np.nan)
        eff_tau160_pt.append(np.nan)
    else:
        eff_tau_pf_pt.append(tau_pf[sel].mean())
        eff_tau_tcp_pt.append(tau_tcp[sel].mean())
        eff_tau160_pt.append(tau160[sel].mean())

plt.figure()
plt.plot(centers, eff_tau_pf_pt, "o", label="tau_pf")
plt.plot(centers, eff_tau_tcp_pt, "o", label="tau_tcp")
plt.plot(centers, eff_tau160_pt, "o", label="tau160")
plt.xlabel("leading tau pT")
plt.legend()
plt.title(f"Tau trigger efficiency vs leading tau pT — {sample_label}")

from pathlib import Path
PLOT_DIR = Path("plots")
PLOT_DIR.mkdir(exist_ok=True)

plt.savefig(PLOT_DIR / "tau_pt_turnon_overlay.png",
            dpi=300,
            bbox_inches="tight")
plt.show()
# Out:
# lead tau pt min/max (GeV): 25.000923828125 472.6046875

# %%
# b-tag trigger efficiency vs leading b-jet pt (b85 jets)
lead_bjet_pt = []
for i in range(len(df)):
    pts = df["jet_pt_NOSYS"][i]                          # jet pts (MeV)
    b85 = df["jet_GN2v01_FixedCutBEff_85_select"][i]     # 0/1 flags

    bpts = []
    for j in range(len(pts)):
        if b85[j] == 1:
            bpts.append(pts[j])

    if len(bpts) > 0:
        lead_bjet_pt.append(max(bpts) / 1000.0)          # GeV
    else:
        lead_bjet_pt.append(np.nan)

lead_bjet_pt = np.array(lead_bjet_pt)
print("lead b-jet pt min/max (GeV):", np.nanmin(lead_bjet_pt), np.nanmax(lead_bjet_pt))
print("fraction of events with >=1 b85 jet:", np.isfinite(lead_bjet_pt).mean())

bins_b = np.linspace(0, 400, 33)
centers = []
eff_j70_bpt = []
eff_j75_bpt = []

for i in range(len(bins_b) - 1):
    lo = bins_b[i]
    hi = bins_b[i + 1]
    sel = (lead_bjet_pt >= lo) & (lead_bjet_pt < hi) & np.isfinite(lead_bjet_pt)
    centers.append((lo + hi) / 2)

    if sel.sum() < 20:    # smaller cutoff because b-jets might be rarer????
        eff_j70_bpt.append(np.nan)
        eff_j75_bpt.append(np.nan)
    else:
        eff_j70_bpt.append(j70[sel].mean())
        eff_j75_bpt.append(j75[sel].mean())

plt.figure()
plt.plot(centers, eff_j70_bpt, "o", label="J70")
plt.plot(centers, eff_j75_bpt, "o", label="J75")
plt.xlabel("leading b-jet pT [GeV] (b85)")
plt.ylabel("efficiency")
plt.ylim(0, 1.05)
plt.legend()
plt.title("B-tag trigger efficiency vs leading b-jet pT")
plt.show()
# Out:
# lead b-jet pt min/max (GeV): 25.0004921875 1533.62225
# fraction of events with >=1 b85 jet: 0.8606020942408377

# %%
print("Trigger Study Summary")

# basic efficiencies
print("Basic efficiencies:")
print(" PF-MET:", round(met_pf.mean(), 3))
print(" J70:",    round(j70.mean(), 3))
print(" J75:",    round(j75.mean(), 3))
print(" TAU pf:", round(tau_pf.mean(), 3))
print(" TAU tcp:", round(tau_tcp.mean(), 3))
print(" TAU160:",  round(tau160.mean(), 3))
# new triggers
print(" J_2J35:", round(j_2j35.mean(), 3))
print(" J_2J45:", round(j_2j45.mean(), 3))
print(" J140_2J50:", round(j140_2j50.mean(), 3))
print(" J150_2J55:", round(j150_2j55.mean(), 3))
print(" J175_J60:", round(j175_j60.mean(), 3))
print(" DITAU_35_25:", round(ditau_35_25.mean(), 3))
print(" DITAU_35_25_J:", round(ditau_35_25_j.mean(), 3))
print(" DITAU_40_35:", round(ditau_40_35.mean(), 3))
print(" DITAU_80_35:", round(ditau_80_35.mean(), 3))
print(" DITAU_80_60:", round(ditau_80_60.mean(), 3))
print()

# overlaps
print("Overlaps with PF-MET:")
j70_only = (j70 & ~met_pf).sum()
j75_only = (j75 & ~met_pf).sum()

if j70.sum() > 0:
    print(" frac(J70 not PF):", round(j70_only / j70.sum(), 3))
if j75.sum() > 0:
    print(" frac(J75 not PF):", round(j75_only / j75.sum(), 3))

tau_only = (tau_pf & ~met_pf).sum()
if tau_pf.sum() > 0:
    print(" frac(tau_pf not PF):", round(tau_only / tau_pf.sum(), 3))

tau160_only = (tau160 & ~met_pf).sum()
if tau160.sum() > 0:
    print(" frac(tau160 not PF):", round(tau160_only / tau160.sum(), 3))

# new-trigger overlaps with PF-MET
for name, mask in [("J_2J35", j_2j35), ("J_2J45", j_2j45),
                   ("J140_2J50", j140_2j50), ("J150_2J55", j150_2j55),
                   ("J175_J60", j175_j60),
                   ("DITAU_35_25", ditau_35_25),
                   ("DITAU_35_25_J", ditau_35_25_j),
                   ("DITAU_40_35", ditau_40_35),
                   ("DITAU_80_35", ditau_80_35),
                   ("DITAU_80_60", ditau_80_60)]:
    only = (mask & ~met_pf).sum()
    if mask.sum() > 0:
        print(f" frac({name} not PF):", round(only / mask.sum(), 3))

print()

# OR gains
print("OR efficiencies:")
print(" PF only:",                  round(met_pf.mean(), 3))
print(" PF OR J70:",                round((met_pf | j70).mean(), 3))
print(" PF OR J75:",                round((met_pf | j75).mean(), 3))
print(" PF OR J70 OR J75:",         round((met_pf | j70 | j75).mean(), 3))
print(" PF OR J70 OR tau:",         round((met_pf | j70 | tau_pf).mean(), 3))
print(" PF OR all (excl tau160):",  round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp).mean(), 3))
print(" PF OR all (incl tau160):",  round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp | tau160).mean(), 3))
print(" TAU160 OR PF_MET:",         round((tau160 | met_pf).mean(), 3))
print(" TAU160 OR J70:",            round((tau160 | j70).mean(), 3))
print()

# new-trigger OR gains
print(" PF OR J_2J45:",             round((met_pf | j_2j45).mean(), 3))
print(" PF OR J_2J35:",             round((met_pf | j_2j35).mean(), 3))
print(" PF OR J140_2J50:",          round((met_pf | j140_2j50).mean(), 3))
print(" PF OR DITAU_35_25:",        round((met_pf | ditau_35_25).mean(), 3))
print(" PF OR DITAU_40_35:",        round((met_pf | ditau_40_35).mean(), 3))
print(" PF OR all new b-tag:",      round((met_pf | j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60).mean(), 3))
print(" PF OR all new di-tau:",     round((met_pf | ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
print(" PF OR all new triggers:",   round((met_pf | j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60 |
                                            ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
print(" PF OR EVERYTHING:",         round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp | tau160 |
                                            j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60 |
                                            ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
# Out:
# Trigger Study Summary
# Basic efficiencies:
#  PF-MET: 0.146
#  J70: 0.048
#  J75: 0.036
#  TAU pf: 0.025
#  TAU tcp: 0.027
#  TAU160: 0.007
#  J_2J35: 0.052
#  J_2J45: 0.064
#  J140_2J50: 0.034
#  J150_2J55: 0.028
#  J175_J60: 0.012
#  DITAU_35_25: 0.022
#  DITAU_35_25_J: 0.017
#  DITAU_40_35: 0.009
#  DITAU_80_35: 0.002
#  DITAU_80_60: 0.001
#
# Overlaps with PF-MET:
#  frac(J70 not PF): 0.719
#  frac(J75 not PF): 0.703
#  frac(tau_pf not PF): 0.265
#  frac(tau160 not PF): 0.672
#  frac(J_2J35 not PF): 0.81
#  frac(J_2J45 not PF): 0.814
#  frac(J140_2J50 not PF): 0.678
#  frac(J150_2J55 not PF): 0.664
#  frac(J175_J60 not PF): 0.677
#  frac(DITAU_35_25 not PF): 0.873
#  frac(DITAU_35_25_J not PF): 0.882
#  frac(DITAU_40_35 not PF): 0.84
#  frac(DITAU_80_35 not PF): 0.75
#  frac(DITAU_80_60 not PF): 0.609
#
# OR efficiencies:
#  PF only: 0.146
#  PF OR J70: 0.181
#  PF OR J75: 0.172
#  PF OR J70 OR J75: 0.181
#  PF OR J70 OR tau: 0.187
#  PF OR all (excl tau160): 0.196
#  PF OR all (incl tau160): 0.199
#  TAU160 OR PF_MET: 0.151
#  TAU160 OR J70: 0.053
#
#  PF OR J_2J45: 0.199
#  PF OR J_2J35: 0.188
#  PF OR J140_2J50: 0.169
#  PF OR DITAU_35_25: 0.165
#  PF OR DITAU_40_35: 0.154
#  PF OR all new b-tag: 0.222
#  PF OR all new di-tau: 0.167
#  PF OR all new triggers: 0.24
#  PF OR EVERYTHING: 0.273

# %%
#  Offline MET cut scan (100→200 GeV, 5 GeV steps) under PF MET trigger 

# Per the meeting: apply PF_MET trigger as the baseline, then sweep the
# offline MET threshold from 100 to 200 GeV in 5-GeV steps to see how
# much efficiency we lose/gain as that cut moves.

cut_values = np.arange(100, 205, 5)   # 100, 105, ..., 200 GeV

# Events that pass the PF MET trigger
pf_mask = met_pf.values    # boolean array

# Total events passing PF trigger (our denominator)
n_pf_total = pf_mask.sum()

effs = []
errors = []

for cut in cut_values:
    passed = (pf_mask & (offline_met_gev >= cut)).sum()
    eff, err = eff_err(passed, n_pf_total)
    effs.append(eff)
    errors.append(err)

effs = np.array(effs)
errors = np.array(errors)

#  Plot 
fig, ax = plt.subplots(figsize=(9, 5))

ax.errorbar(cut_values, effs, yerr=errors, fmt='o-', color='steelblue',
            capsize=3, label='PF MET trigger + offline cut')
ax.axvline(150, color='red', linestyle='--', label='Current cut (150 GeV)')
import matplotlib.pyplot as plt
plt.axhline(y=0.4544, color='green', linestyle='--')

ax.set_xlabel('Offline MET cut [GeV]')
ax.set_ylabel('Efficiency (events passing trigger AND cut / events passing trigger)')
ax.set_ylim(0, 1.05)
ax.set_title(f'Efficiency vs offline MET cut — {sample_label} (PF MET baseline)')
ax.legend()
plt.tight_layout()
plt.show()

#  Numeric table 
print(f"\n=== Offline MET cut scan — {sample_label} (denominator = PF MET trigger events: {n_pf_total}) ===")
print(f"{'Cut [GeV]':>10}  {'Efficiency':>12}  {'Unc':>8}  {'Rel. to 150 GeV':>16}")
print("-" * 55)

ref_eff = effs[cut_values == 150][0]
for c, e, s in zip(cut_values, effs, errors):
    delta = e - ref_eff
    marker = " ← current" if c == 150 else ""
    print(f"{c:10.0f}  {e:12.4f}  {s:8.4f}  {delta:+.4f}{marker}")
# Out:
# === Offline MET cut scan — jet80 (denominator = PF MET trigger events: 14314) ===
#  Cut [GeV]    Efficiency       Unc   Rel. to 150 GeV
# -------------------------------------------------------
#        100        0.8460    0.0030  +0.4138
#        105        0.8134    0.0033  +0.3812
#        110        0.7757    0.0035  +0.3434
#        115        0.7361    0.0037  +0.3039
#        120        0.6904    0.0039  +0.2582
#        125        0.6464    0.0040  +0.2141
#        130        0.6012    0.0041  +0.1690
#        135        0.5583    0.0042  +0.1260
#        140        0.5135    0.0042  +0.0812
#        145        0.4717    0.0042  +0.0395
#        150        0.4322    0.0041  +0.0000 ← current
#        155        0.3943    0.0041  -0.0379
#        160        0.3587    0.0040  -0.0736
#        165        0.3255    0.0039  -0.1067
#        170        0.2950    0.0038  -0.1373
#        175        0.2683    0.0037  -0.1639
#        180        0.2441    0.0036  -0.1881
#        185        0.2193    0.0035  -0.2129
#        190        0.1981    0.0033  -0.2342
#        195        0.1807    0.0032  -0.2516
#        200        0.1639    0.0031  -0.2683
