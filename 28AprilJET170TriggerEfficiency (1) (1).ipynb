# %%
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pathlib import Path
# folder containing: jet80, jet170, jet1000, lep80, lep170, lep1000
file_path = Path("/Users/lydiaamstutz/Downloads/jet170update.root")
sample_label = "jet170"
print("Opening:", file_path)
file = uproot.open(file_path)
print("File keys:", file.keys())
# Out:
# Opening: /Users/lydiaamstutz/Downloads/jet170update.root
# File keys: ['EventLoop_OutputStream_ANALYSIS;1', 'EventLoop_FileExecuted;1', 'EventLoop_JobStats;1', 'listOfSystematics;1', 'metadata;1', 'cflow_AnaElectrons_tight_NOSYS;1', 'cflow_AnaMuons_tight_NOSYS;1', 'cflow_AnaTauJets_tight_NOSYS;1', 'cflow_AnaJets_baselineJvt_NOSYS;1', 'cflow_EventInfo__TAUJETcommon_NOSYS;1', 'cflow_EventInfo__TAUELcommon_NOSYS;1', 'cflow_EventInfo__TAUMUcommon_NOSYS;1', 'cflow_EventInfo__DILEPcommon_NOSYS;1', 'CutBookkeeper_569176_450000_NOSYS;1', 'EventLoop_RunTime;1', 'EventLoop_EventCount;1', 'reco;1']

# %%
# try the expected tree first
if "reco" in file:
    tree = file["reco"]
else:
    # show what trees exist so i can pick the right one
    print("Top-level keys:", file.keys())
    raise KeyError("Tree 'reco' not found. Pick the correct tree from file.keys().")

print("Tree loaded:", tree)
print("N entries:", tree.num_entries)
# Out:
# Tree loaded: <TTree 'reco' (148 branches) at 0x0001051b3a10>
# N entries: 97892

# %%
# find what the tau trigger branches are actually called in this ntuple
keys = tree.keys()
tau_like = [k for k in keys if ("trigPassed_HLT_tau" in k) or ("tau50" in k) or ("mediumRNN" in k)]
print("found", len(tau_like), "tau-ish branches")
for k in tau_like[:80]:
    print(k)
# Out:
# found 8 tau-ish branches
# trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100
# trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25
# trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25
# trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20
# trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50
# trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50
# trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I
# trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40

# %%
# find tau pt branch name in this ntuple
tau_pt_candidates = [k for k in tree.keys() if ("tau" in k.lower()) and ("pt" in k.lower())]
print("tau pt candidates:", tau_pt_candidates)
# Out:
# tau pt candidates: ['tau_truth_pt_invis', 'tau_truth_pt_vis', 'tau_pt_NOSYS']

# %%
# find jet pt branch name in this ntuple
jet_pt_candidates = [k for k in tree.keys() if ("jet" in k.lower()) and ("pt" in k.lower())]
print("jet pt candidates:", jet_pt_candidates)
# Out:
# jet pt candidates: ['jet_pt_NOSYS']

# %%
##check that the file loaded correctly
branches = [
    "eventNumber",
    "met_met_NOSYS",
    "trigPassed_HLT_xe65_cell_xe90_pfopufit_L1XE50",
    "trigPassed_HLT_xe80_cell_xe115_tcpufit_L1XE50",
    "trigPassed_HLT_j70_0eta290_020jvt_bgn160_3j70_pf_ftf_preselj50b85XX3j50_L14J20",
    "trigPassed_HLT_j75_0eta290_020jvt_bgn160_3j75_pf_ftf_preselj50b85XX3j50_L14J20",
    "tau_pt_NOSYS",
    "jet_pt_NOSYS",
    "jet_GN2v01_FixedCutBEff_85_select",
]

#add the taus
branches += [
    "trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50",
    "trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50",
    "trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100",
]

branches += [
    "trigPassed_HLT_2j35_0eta290_020jvt_bgn160_3j35_pf_ftf_presel3j25XX2j25b85_L15J15p0ETA25",   # J_2J35
    "trigPassed_HLT_2j45_0eta290_020jvt_bgn160_2j45_pf_ftf_presel2j25XX2j25b85_L14J15p0ETA25",   # J_2J45
    "trigPassed_HLT_j140_2j50_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30",   # J140_2J50
    "trigPassed_HLT_j150_2j55_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30",   # J150_2J55
    "trigPassed_HLT_j175_0eta290_020jvt_bgn160_j60_0eta290_020jvt_bgn160_pf_ftf_preselj140b85XXj45b85_L1J100",   # J175_J60
    "trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25",   # DITAU_35_25
    "trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25",   # DITAU_35_25_J
    "trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20",   # DITAU_40_35
    "trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I",   # DITAU_80_35
    "trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40",   # DITAU_80_60
]

arr = tree.arrays(branches, library="ak")
data = {}
for k in branches:
    if arr[k].ndim == 1:
        data[k] = np.array(arr[k])
    else:
        data[k] = arr[k].to_list()

df = pd.DataFrame(data)

offline_met_gev = df["met_met_NOSYS"].values / 1000.0

# %%
print("rows:", len(df))
print("unique events:", df["eventNumber"].nunique())
print("any NaNs in MET:", df["met_met_NOSYS"].isna().any())
print("MET min/max:", df["met_met_NOSYS"].min(), df["met_met_NOSYS"].max())
# Out:
# rows: 97892
# unique events: 97892
# any NaNs in MET: False
# MET min/max: 97.07833862304688 1407470.875

# %%
met_pf = (df["trigPassed_HLT_xe65_cell_xe90_pfopufit_L1XE50"] == 1)
met_hi = (df["trigPassed_HLT_xe80_cell_xe115_tcpufit_L1XE50"] == 1)
j70 = (df["trigPassed_HLT_j70_0eta290_020jvt_bgn160_3j70_pf_ftf_preselj50b85XX3j50_L14J20"] == 1)
j75 = (df["trigPassed_HLT_j75_0eta290_020jvt_bgn160_3j75_pf_ftf_preselj50b85XX3j50_L14J20"] == 1)
tau_tcp = (df["trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_tcpufit_xe50_cell_L1XE50"] == 1)
tau_pf = (df["trigPassed_HLT_tau50_mediumRNN_tracktwoMVA_xe80_pfopufit_xe50_cell_L1XE50"] == 1)
tau160 = (df["trigPassed_HLT_tau160_mediumRNN_tracktwoMVA_L1TAU100"] == 1)

# new triggers from the *update.root file
j_2j35 = (df["trigPassed_HLT_2j35_0eta290_020jvt_bgn160_3j35_pf_ftf_presel3j25XX2j25b85_L15J15p0ETA25"] == 1)
j_2j45 = (df["trigPassed_HLT_2j45_0eta290_020jvt_bgn160_2j45_pf_ftf_presel2j25XX2j25b85_L14J15p0ETA25"] == 1)
j140_2j50 = (df["trigPassed_HLT_j140_2j50_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30"] == 1)
j150_2j55 = (df["trigPassed_HLT_j150_2j55_0eta290_020jvt_bgn170_pf_ftf_preselj80XX2j45b90_L1J85_3J30"] == 1)
j175_j60 = (df["trigPassed_HLT_j175_0eta290_020jvt_bgn160_j60_0eta290_020jvt_bgn160_pf_ftf_preselj140b85XXj45b85_L1J100"] == 1)
ditau_35_25 = (df["trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB_L1TAU20IM_2TAU12IM_4J12p0ETA25"] == 1)
ditau_35_25_j = (df["trigPassed_HLT_tau35_mediumRNN_tracktwoMVA_tau25_mediumRNN_tracktwoMVA_03dRAB30_L1DR_TAU20ITAU12I_J25"] == 1)
ditau_40_35 = (df["trigPassed_HLT_tau40_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB_L1TAU25IM_2TAU20IM_2J25_3J20"] == 1)
ditau_80_35 = (df["trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau35_mediumRNN_tracktwoMVA_03dRAB30_L1TAU60_DR_TAU20ITAU12I"] == 1)
ditau_80_60 = (df["trigPassed_HLT_tau80_mediumRNN_tracktwoMVA_tau60_mediumRNN_tracktwoMVA_03dRAB_L1TAU60_2TAU40"] == 1)

# %%
from itertools import combinations

base = {
    "PF_MET":      met_pf,
    "TCP_MET":     met_hi,
    "J70":         j70,
    "J75":         j75,
    "TAU+MET_PF":  tau_pf,
    "TAU+MET_TCP": tau_tcp,
    "TAU160":      tau160,
    # new triggers
    "J_2J35": j_2j35,
    "J_2J45": j_2j45,
    "J140_2J50": j140_2j50,
    "J150_2J55": j150_2j55,
    "J175_J60": j175_j60,
    "DITAU_35_25": ditau_35_25,
    "DITAU_35_25_J": ditau_35_25_j,
    "DITAU_40_35": ditau_40_35,
    "DITAU_80_35": ditau_80_35,
    "DITAU_80_60": ditau_80_60,
}

# Sanity check: any banch thatfires on 0 events is likely unfilled in
zero_fire = [name for name, m in base.items() if m.sum() == 0]
if zero_fire:
    print("[WARNING] These trigger branches fire on 0 events -- likely unfilled:")
    for n in zero_fire:
        print(f"   - {n}")
    print()

# build all or/and combos
OR = {}
AND = {}
for a, b in combinations(base.keys(), 2):
    OR[f"{a} OR {b}"] = base[a] | base[b]
    AND[f"{a} AND {b}"] = base[a] & base[b]

print(f"Built {len(OR)} OR combos and {len(AND)} AND combos.")

# Overall efficiencies: triggers
print("\n=== Overall efficiencies (Triggers) ===")
for name in base:
    print(f"{name:15s}  eff={base[name].mean():.4f}  passed={base[name].sum()}")

# Overall efficiencies: all ORs
print("\n=== Overall efficiencies (All OR combos) ===")
for name in sorted(OR.keys()):
    print(f"{name:55s} eff={OR[name].mean():.4f}")

# Overall efficiencies: all ANDs
print("\n=== Overall efficiencies (All AND combos) ===")
for name in sorted(AND.keys()):
    print(f"{name:55s} eff={AND[name].mean():.4f}")

# A few specific combos
print("\n=== Specific combos ===")
print("PF_MET OR TAU+MET_PF:", OR["PF_MET OR TAU+MET_PF"].mean())
print("J70 OR TAU+MET_PF:",    OR["J70 OR TAU+MET_PF"].mean())
print("PF_MET OR J70:",        OR["PF_MET OR J70"].mean())
# Out:
# Built 136 OR combos and 136 AND combos.
#
# === Overall efficiencies (Triggers) ===
# PF_MET           eff=0.3247  passed=31788
# TCP_MET          eff=0.2264  passed=22165
# J70              eff=0.0300  passed=2936
# J75              eff=0.0215  passed=2106
# TAU+MET_PF       eff=0.1085  passed=10623
# TAU+MET_TCP      eff=0.1107  passed=10840
# TAU160           eff=0.0318  passed=3115
# J_2J35           eff=0.0261  passed=2551
# J_2J45           eff=0.0332  passed=3249
# J140_2J50        eff=0.0213  passed=2086
# J150_2J55        eff=0.0178  passed=1743
# J175_J60         eff=0.0095  passed=926
# DITAU_35_25      eff=0.0318  passed=3111
# DITAU_35_25_J    eff=0.0271  passed=2650
# DITAU_40_35      eff=0.0167  passed=1638
# DITAU_80_35      eff=0.0060  passed=591
# DITAU_80_60      eff=0.0041  passed=404
#
# === Overall efficiencies (All OR combos) ===
# DITAU_35_25 OR DITAU_35_25_J                            eff=0.0364
# DITAU_35_25 OR DITAU_40_35                              eff=0.0345
# DITAU_35_25 OR DITAU_80_35                              eff=0.0326
# DITAU_35_25 OR DITAU_80_60                              eff=0.0328
# DITAU_35_25_J OR DITAU_40_35                            eff=0.0324
# DITAU_35_25_J OR DITAU_80_35                            eff=0.0272
# DITAU_35_25_J OR DITAU_80_60                            eff=0.0289
# DITAU_40_35 OR DITAU_80_35                              eff=0.0177
# DITAU_40_35 OR DITAU_80_60                              eff=0.0172
# DITAU_80_35 OR DITAU_80_60                              eff=0.0079
# J140_2J50 OR DITAU_35_25                                eff=0.0517
# J140_2J50 OR DITAU_35_25_J                              eff=0.0473
# J140_2J50 OR DITAU_40_35                                eff=0.0370
# J140_2J50 OR DITAU_80_35                                eff=0.0268
# J140_2J50 OR DITAU_80_60                                eff=0.0250
# J140_2J50 OR J150_2J55                                  eff=0.0213
# J140_2J50 OR J175_J60                                   eff=0.0238
# J150_2J55 OR DITAU_35_25                                eff=0.0484
# J150_2J55 OR DITAU_35_25_J                              eff=0.0440
# J150_2J55 OR DITAU_40_35                                eff=0.0337
# J150_2J55 OR DITAU_80_35                                eff=0.0234
# J150_2J55 OR DITAU_80_60                                eff=0.0215
# J150_2J55 OR J175_J60                                   eff=0.0204
# J175_J60 OR DITAU_35_25                                 eff=0.0407
# J175_J60 OR DITAU_35_25_J                               eff=0.0361
# J175_J60 OR DITAU_40_35                                 eff=0.0258
# J175_J60 OR DITAU_80_35                                 eff=0.0153
# J175_J60 OR DITAU_80_60                                 eff=0.0134
# J70 OR DITAU_35_25                                      eff=0.0601
# J70 OR DITAU_35_25_J                                    eff=0.0559
# J70 OR DITAU_40_35                                      eff=0.0454
# J70 OR DITAU_80_35                                      eff=0.0353
# J70 OR DITAU_80_60                                      eff=0.0334
# J70 OR J140_2J50                                        eff=0.0437
# J70 OR J150_2J55                                        eff=0.0410
# J70 OR J175_J60                                         eff=0.0364
# J70 OR J75                                              eff=0.0300
# J70 OR J_2J35                                           eff=0.0495
# J70 OR J_2J45                                           eff=0.0548
# J70 OR TAU+MET_PF                                       eff=0.1286
# J70 OR TAU+MET_TCP                                      eff=0.1307
# J70 OR TAU160                                           eff=0.0571
# J75 OR DITAU_35_25                                      eff=0.0521
# J75 OR DITAU_35_25_J                                    eff=0.0477
# J75 OR DITAU_40_35                                      eff=0.0372
# J75 OR DITAU_80_35                                      eff=0.0269
# J75 OR DITAU_80_60                                      eff=0.0250
# J75 OR J140_2J50                                        eff=0.0366
# J75 OR J150_2J55                                        eff=0.0337
# J75 OR J175_J60                                         eff=0.0284
# J75 OR J_2J35                                           eff=0.0428
# J75 OR J_2J45                                           eff=0.0484
# J75 OR TAU+MET_PF                                       eff=0.1225
# J75 OR TAU+MET_TCP                                      eff=0.1247
# J75 OR TAU160                                           eff=0.0494
# J_2J35 OR DITAU_35_25                                   eff=0.0559
# J_2J35 OR DITAU_35_25_J                                 eff=0.0517
# J_2J35 OR DITAU_40_35                                   eff=0.0418
# J_2J35 OR DITAU_80_35                                   eff=0.0317
# J_2J35 OR DITAU_80_60                                   eff=0.0300
# J_2J35 OR J140_2J50                                     eff=0.0399
# J_2J35 OR J150_2J55                                     eff=0.0377
# J_2J35 OR J175_J60                                      eff=0.0317
# J_2J35 OR J_2J45                                        eff=0.0401
# J_2J45 OR DITAU_35_25                                   eff=0.0631
# J_2J45 OR DITAU_35_25_J                                 eff=0.0589
# J_2J45 OR DITAU_40_35                                   eff=0.0487
# J_2J45 OR DITAU_80_35                                   eff=0.0388
# J_2J45 OR DITAU_80_60                                   eff=0.0370
# J_2J45 OR J140_2J50                                     eff=0.0428
# J_2J45 OR J150_2J55                                     eff=0.0412
# J_2J45 OR J175_J60                                      eff=0.0364
# PF_MET OR DITAU_35_25                                   eff=0.3469
# PF_MET OR DITAU_35_25_J                                 eff=0.3436
# PF_MET OR DITAU_40_35                                   eff=0.3358
# PF_MET OR DITAU_80_35                                   eff=0.3285
# PF_MET OR DITAU_80_60                                   eff=0.3266
# PF_MET OR J140_2J50                                     eff=0.3339
# PF_MET OR J150_2J55                                     eff=0.3321
# PF_MET OR J175_J60                                      eff=0.3281
# PF_MET OR J70                                           eff=0.3398
# PF_MET OR J75                                           eff=0.3352
# PF_MET OR J_2J35                                        eff=0.3400
# PF_MET OR J_2J45                                        eff=0.3437
# PF_MET OR TAU+MET_PF                                    eff=0.3497
# PF_MET OR TAU+MET_TCP                                   eff=0.3591
# PF_MET OR TAU160                                        eff=0.3465
# PF_MET OR TCP_MET                                       eff=0.3319
# TAU+MET_PF OR DITAU_35_25                               eff=0.1308
# TAU+MET_PF OR DITAU_35_25_J                             eff=0.1274
# TAU+MET_PF OR DITAU_40_35                               eff=0.1189
# TAU+MET_PF OR DITAU_80_35                               eff=0.1119
# TAU+MET_PF OR DITAU_80_60                               eff=0.1102
# TAU+MET_PF OR J140_2J50                                 eff=0.1239
# TAU+MET_PF OR J150_2J55                                 eff=0.1211
# TAU+MET_PF OR J175_J60                                  eff=0.1156
# TAU+MET_PF OR J_2J35                                    eff=0.1295
# TAU+MET_PF OR J_2J45                                    eff=0.1352
# TAU+MET_PF OR TAU+MET_TCP                               eff=0.1252
# TAU+MET_PF OR TAU160                                    eff=0.1282
# TAU+MET_TCP OR DITAU_35_25                              eff=0.1330
# TAU+MET_TCP OR DITAU_35_25_J                            eff=0.1297
# TAU+MET_TCP OR DITAU_40_35                              eff=0.1210
# TAU+MET_TCP OR DITAU_80_35                              eff=0.1140
# TAU+MET_TCP OR DITAU_80_60                              eff=0.1124
# TAU+MET_TCP OR J140_2J50                                eff=0.1259
# TAU+MET_TCP OR J150_2J55                                eff=0.1233
# TAU+MET_TCP OR J175_J60                                 eff=0.1178
# TAU+MET_TCP OR J_2J35                                   eff=0.1317
# TAU+MET_TCP OR J_2J45                                   eff=0.1373
# TAU+MET_TCP OR TAU160                                   eff=0.1292
# TAU160 OR DITAU_35_25                                   eff=0.0600
# TAU160 OR DITAU_35_25_J                                 eff=0.0562
# TAU160 OR DITAU_40_35                                   eff=0.0453
# TAU160 OR DITAU_80_35                                   eff=0.0357
# TAU160 OR DITAU_80_60                                   eff=0.0334
# TAU160 OR J140_2J50                                     eff=0.0499
# TAU160 OR J150_2J55                                     eff=0.0466
# TAU160 OR J175_J60                                      eff=0.0401
# TAU160 OR J_2J35                                        eff=0.0563
# TAU160 OR J_2J45                                        eff=0.0628
# TCP_MET OR DITAU_35_25                                  eff=0.2516
# TCP_MET OR DITAU_35_25_J                                eff=0.2479
# TCP_MET OR DITAU_40_35                                  eff=0.2389
# TCP_MET OR DITAU_80_35                                  eff=0.2306
# TCP_MET OR DITAU_80_60                                  eff=0.2284
# TCP_MET OR J140_2J50                                    eff=0.2376
# TCP_MET OR J150_2J55                                    eff=0.2355
# TCP_MET OR J175_J60                                     eff=0.2307
# TCP_MET OR J70                                          eff=0.2443
# TCP_MET OR J75                                          eff=0.2389
# TCP_MET OR J_2J35                                       eff=0.2445
# TCP_MET OR J_2J45                                       eff=0.2490
# TCP_MET OR TAU+MET_PF                                   eff=0.2793
# TCP_MET OR TAU+MET_TCP                                  eff=0.2798
# TCP_MET OR TAU160                                       eff=0.2498
#
# === Overall efficiencies (All AND combos) ===
# DITAU_35_25 AND DITAU_35_25_J                           eff=0.0225
# DITAU_35_25 AND DITAU_40_35                             eff=0.0140
# DITAU_35_25 AND DITAU_80_35                             eff=0.0052
# DITAU_35_25 AND DITAU_80_60                             eff=0.0031
# DITAU_35_25_J AND DITAU_40_35                           eff=0.0114
# DITAU_35_25_J AND DITAU_80_35                           eff=0.0059
# DITAU_35_25_J AND DITAU_80_60                           eff=0.0023
# DITAU_40_35 AND DITAU_80_35                             eff=0.0051
# DITAU_40_35 AND DITAU_80_60                             eff=0.0037
# DITAU_80_35 AND DITAU_80_60                             eff=0.0022
# J140_2J50 AND DITAU_35_25                               eff=0.0014
# J140_2J50 AND DITAU_35_25_J                             eff=0.0011
# J140_2J50 AND DITAU_40_35                               eff=0.0010
# J140_2J50 AND DITAU_80_35                               eff=0.0006
# J140_2J50 AND DITAU_80_60                               eff=0.0004
# J140_2J50 AND J150_2J55                                 eff=0.0178
# J140_2J50 AND J175_J60                                  eff=0.0070
# J150_2J55 AND DITAU_35_25                               eff=0.0012
# J150_2J55 AND DITAU_35_25_J                             eff=0.0009
# J150_2J55 AND DITAU_40_35                               eff=0.0009
# J150_2J55 AND DITAU_80_35                               eff=0.0005
# J150_2J55 AND DITAU_80_60                               eff=0.0004
# J150_2J55 AND J175_J60                                  eff=0.0069
# J175_J60 AND DITAU_35_25                                eff=0.0006
# J175_J60 AND DITAU_35_25_J                              eff=0.0004
# J175_J60 AND DITAU_40_35                                eff=0.0004
# J175_J60 AND DITAU_80_35                                eff=0.0002
# J175_J60 AND DITAU_80_60                                eff=0.0002
# J70 AND DITAU_35_25                                     eff=0.0016
# J70 AND DITAU_35_25_J                                   eff=0.0012
# J70 AND DITAU_40_35                                     eff=0.0013
# J70 AND DITAU_80_35                                     eff=0.0008
# J70 AND DITAU_80_60                                     eff=0.0007
# J70 AND J140_2J50                                       eff=0.0076
# J70 AND J150_2J55                                       eff=0.0068
# J70 AND J175_J60                                        eff=0.0030
# J70 AND J75                                             eff=0.0215
# J70 AND J_2J35                                          eff=0.0065
# J70 AND J_2J45                                          eff=0.0084
# J70 AND TAU+MET_PF                                      eff=0.0099
# J70 AND TAU+MET_TCP                                     eff=0.0100
# J70 AND TAU160                                          eff=0.0047
# J75 AND DITAU_35_25                                     eff=0.0012
# J75 AND DITAU_35_25_J                                   eff=0.0009
# J75 AND DITAU_40_35                                     eff=0.0010
# J75 AND DITAU_80_35                                     eff=0.0006
# J75 AND DITAU_80_60                                     eff=0.0006
# J75 AND J140_2J50                                       eff=0.0062
# J75 AND J150_2J55                                       eff=0.0056
# J75 AND J175_J60                                        eff=0.0025
# J75 AND J_2J35                                          eff=0.0048
# J75 AND J_2J45                                          eff=0.0063
# J75 AND TAU+MET_PF                                      eff=0.0075
# J75 AND TAU+MET_TCP                                     eff=0.0075
# J75 AND TAU160                                          eff=0.0040
# J_2J35 AND DITAU_35_25                                  eff=0.0019
# J_2J35 AND DITAU_35_25_J                                eff=0.0014
# J_2J35 AND DITAU_40_35                                  eff=0.0010
# J_2J35 AND DITAU_80_35                                  eff=0.0004
# J_2J35 AND DITAU_80_60                                  eff=0.0002
# J_2J35 AND J140_2J50                                    eff=0.0075
# J_2J35 AND J150_2J55                                    eff=0.0062
# J_2J35 AND J175_J60                                     eff=0.0039
# J_2J35 AND J_2J45                                       eff=0.0192
# J_2J45 AND DITAU_35_25                                  eff=0.0019
# J_2J45 AND DITAU_35_25_J                                eff=0.0013
# J_2J45 AND DITAU_40_35                                  eff=0.0012
# J_2J45 AND DITAU_80_35                                  eff=0.0004
# J_2J45 AND DITAU_80_60                                  eff=0.0003
# J_2J45 AND J140_2J50                                    eff=0.0117
# J_2J45 AND J150_2J55                                    eff=0.0098
# J_2J45 AND J175_J60                                     eff=0.0062
# PF_MET AND DITAU_35_25                                  eff=0.0096
# PF_MET AND DITAU_35_25_J                                eff=0.0082
# PF_MET AND DITAU_40_35                                  eff=0.0056
# PF_MET AND DITAU_80_35                                  eff=0.0022
# PF_MET AND DITAU_80_60                                  eff=0.0022
# PF_MET AND J140_2J50                                    eff=0.0121
# PF_MET AND J150_2J55                                    eff=0.0104
# PF_MET AND J175_J60                                     eff=0.0060
# PF_MET AND J70                                          eff=0.0149
# PF_MET AND J75                                          eff=0.0110
# PF_MET AND J_2J35                                       eff=0.0107
# PF_MET AND J_2J45                                       eff=0.0142
# PF_MET AND TAU+MET_PF                                   eff=0.0835
# PF_MET AND TAU+MET_TCP                                  eff=0.0764
# PF_MET AND TAU160                                       eff=0.0100
# PF_MET AND TCP_MET                                      eff=0.2193
# TAU+MET_PF AND DITAU_35_25                              eff=0.0095
# TAU+MET_PF AND DITAU_35_25_J                            eff=0.0082
# TAU+MET_PF AND DITAU_40_35                              eff=0.0063
# TAU+MET_PF AND DITAU_80_35                              eff=0.0026
# TAU+MET_PF AND DITAU_80_60                              eff=0.0024
# TAU+MET_PF AND J140_2J50                                eff=0.0060
# TAU+MET_PF AND J150_2J55                                eff=0.0052
# TAU+MET_PF AND J175_J60                                 eff=0.0024
# TAU+MET_PF AND J_2J35                                   eff=0.0051
# TAU+MET_PF AND J_2J45                                   eff=0.0065
# TAU+MET_PF AND TAU+MET_TCP                              eff=0.0940
# TAU+MET_PF AND TAU160                                   eff=0.0121
# TAU+MET_TCP AND DITAU_35_25                             eff=0.0095
# TAU+MET_TCP AND DITAU_35_25_J                           eff=0.0081
# TAU+MET_TCP AND DITAU_40_35                             eff=0.0064
# TAU+MET_TCP AND DITAU_80_35                             eff=0.0028
# TAU+MET_TCP AND DITAU_80_60                             eff=0.0025
# TAU+MET_TCP AND J140_2J50                               eff=0.0061
# TAU+MET_TCP AND J150_2J55                               eff=0.0052
# TAU+MET_TCP AND J175_J60                                eff=0.0024
# TAU+MET_TCP AND J_2J35                                  eff=0.0051
# TAU+MET_TCP AND J_2J45                                  eff=0.0067
# TAU+MET_TCP AND TAU160                                  eff=0.0133
# TAU160 AND DITAU_35_25                                  eff=0.0036
# TAU160 AND DITAU_35_25_J                                eff=0.0027
# TAU160 AND DITAU_40_35                                  eff=0.0033
# TAU160 AND DITAU_80_35                                  eff=0.0021
# TAU160 AND DITAU_80_60                                  eff=0.0025
# TAU160 AND J140_2J50                                    eff=0.0032
# TAU160 AND J150_2J55                                    eff=0.0030
# TAU160 AND J175_J60                                     eff=0.0012
# TAU160 AND J_2J35                                       eff=0.0016
# TAU160 AND J_2J45                                       eff=0.0022
# TCP_MET AND DITAU_35_25                                 eff=0.0066
# TCP_MET AND DITAU_35_25_J                               eff=0.0055
# TCP_MET AND DITAU_40_35                                 eff=0.0042
# TCP_MET AND DITAU_80_35                                 eff=0.0019
# TCP_MET AND DITAU_80_60                                 eff=0.0021
# TCP_MET AND J140_2J50                                   eff=0.0102
# TCP_MET AND J150_2J55                                   eff=0.0088
# TCP_MET AND J175_J60                                    eff=0.0052
# TCP_MET AND J70                                         eff=0.0121
# TCP_MET AND J75                                         eff=0.0091
# TCP_MET AND J_2J35                                      eff=0.0080
# TCP_MET AND J_2J45                                      eff=0.0106
# TCP_MET AND TAU+MET_PF                                  eff=0.0556
# TCP_MET AND TAU+MET_TCP                                 eff=0.0574
# TCP_MET AND TAU160                                      eff=0.0084
#
# === Specific combos ===
# PF_MET OR TAU+MET_PF: 0.34974257344828996
# J70 OR TAU+MET_PF: 0.1285600457647203
# PF_MET OR J70: 0.3397724022392024

# %%
from itertools import combinations

print("\n=== Overlap counts (A only / B only / both / neither) ===")
for a, b in combinations(base.keys(), 2):
    A = base[a]
    B = base[b]
    a_only = (A & ~B).sum()
    b_only = (~A & B).sum()
    both   = (A & B).sum()
    neither= (~A & ~B).sum()

    # usefl fractions (avoid divide-by-zero)
    frac_a_not_b = (a_only / A.sum()) if A.sum() > 0 else np.nan
    frac_b_not_a = (b_only / B.sum()) if B.sum() > 0 else np.nan

    print(f"{a:14s} vs {b:14s} | "
          f"Aonly={a_only:7d} Bonly={b_only:7d} both={both:7d} neither={neither:7d} | "
          f"frac(A not B)={frac_a_not_b:.3f}  frac(B not A)={frac_b_not_a:.3f}")
# Out:
# === Overlap counts (A only / B only / both / neither) ===
# PF_MET         vs TCP_MET        | Aonly=  10322 Bonly=    699 both=  21466 neither=  65405 | frac(A not B)=0.325  frac(B not A)=0.032
# PF_MET         vs J70            | Aonly=  30325 Bonly=   1473 both=   1463 neither=  64631 | frac(A not B)=0.954  frac(B not A)=0.502
# PF_MET         vs J75            | Aonly=  30711 Bonly=   1029 both=   1077 neither=  65075 | frac(A not B)=0.966  frac(B not A)=0.489
# PF_MET         vs TAU+MET_PF     | Aonly=  23614 Bonly=   2449 both=   8174 neither=  63655 | frac(A not B)=0.743  frac(B not A)=0.231
# PF_MET         vs TAU+MET_TCP    | Aonly=  24313 Bonly=   3365 both=   7475 neither=  62739 | frac(A not B)=0.765  frac(B not A)=0.310
# PF_MET         vs TAU160         | Aonly=  30805 Bonly=   2132 both=    983 neither=  63972 | frac(A not B)=0.969  frac(B not A)=0.684
# PF_MET         vs J_2J35         | Aonly=  30736 Bonly=   1499 both=   1052 neither=  64605 | frac(A not B)=0.967  frac(B not A)=0.588
# PF_MET         vs J_2J45         | Aonly=  30399 Bonly=   1860 both=   1389 neither=  64244 | frac(A not B)=0.956  frac(B not A)=0.572
# PF_MET         vs J140_2J50      | Aonly=  30600 Bonly=    898 both=   1188 neither=  65206 | frac(A not B)=0.963  frac(B not A)=0.430
# PF_MET         vs J150_2J55      | Aonly=  30769 Bonly=    724 both=   1019 neither=  65380 | frac(A not B)=0.968  frac(B not A)=0.415
# PF_MET         vs J175_J60       | Aonly=  31197 Bonly=    335 both=    591 neither=  65769 | frac(A not B)=0.981  frac(B not A)=0.362
# PF_MET         vs DITAU_35_25    | Aonly=  30849 Bonly=   2172 both=    939 neither=  63932 | frac(A not B)=0.970  frac(B not A)=0.698
# PF_MET         vs DITAU_35_25_J  | Aonly=  30985 Bonly=   1847 both=    803 neither=  64257 | frac(A not B)=0.975  frac(B not A)=0.697
# PF_MET         vs DITAU_40_35    | Aonly=  31239 Bonly=   1089 both=    549 neither=  65015 | frac(A not B)=0.983  frac(B not A)=0.665
# PF_MET         vs DITAU_80_35    | Aonly=  31569 Bonly=    372 both=    219 neither=  65732 | frac(A not B)=0.993  frac(B not A)=0.629
# PF_MET         vs DITAU_80_60    | Aonly=  31570 Bonly=    186 both=    218 neither=  65918 | frac(A not B)=0.993  frac(B not A)=0.460
# TCP_MET        vs J70            | Aonly=  20976 Bonly=   1747 both=   1189 neither=  73980 | frac(A not B)=0.946  frac(B not A)=0.595
# TCP_MET        vs J75            | Aonly=  21277 Bonly=   1218 both=    888 neither=  74509 | frac(A not B)=0.960  frac(B not A)=0.578
# TCP_MET        vs TAU+MET_PF     | Aonly=  16718 Bonly=   5176 both=   5447 neither=  70551 | frac(A not B)=0.754  frac(B not A)=0.487
# TCP_MET        vs TAU+MET_TCP    | Aonly=  16549 Bonly=   5224 both=   5616 neither=  70503 | frac(A not B)=0.747  frac(B not A)=0.482
# TCP_MET        vs TAU160         | Aonly=  21338 Bonly=   2288 both=    827 neither=  73439 | frac(A not B)=0.963  frac(B not A)=0.735
# TCP_MET        vs J_2J35         | Aonly=  21379 Bonly=   1765 both=    786 neither=  73962 | frac(A not B)=0.965  frac(B not A)=0.692
# TCP_MET        vs J_2J45         | Aonly=  21125 Bonly=   2209 both=   1040 neither=  73518 | frac(A not B)=0.953  frac(B not A)=0.680
# TCP_MET        vs J140_2J50      | Aonly=  21169 Bonly=   1090 both=    996 neither=  74637 | frac(A not B)=0.955  frac(B not A)=0.523
# TCP_MET        vs J150_2J55      | Aonly=  21306 Bonly=    884 both=    859 neither=  74843 | frac(A not B)=0.961  frac(B not A)=0.507
# TCP_MET        vs J175_J60       | Aonly=  21656 Bonly=    417 both=    509 neither=  75310 | frac(A not B)=0.977  frac(B not A)=0.450
# TCP_MET        vs DITAU_35_25    | Aonly=  21518 Bonly=   2464 both=    647 neither=  73263 | frac(A not B)=0.971  frac(B not A)=0.792
# TCP_MET        vs DITAU_35_25_J  | Aonly=  21622 Bonly=   2107 both=    543 neither=  73620 | frac(A not B)=0.976  frac(B not A)=0.795
# TCP_MET        vs DITAU_40_35    | Aonly=  21749 Bonly=   1222 both=    416 neither=  74505 | frac(A not B)=0.981  frac(B not A)=0.746
# TCP_MET        vs DITAU_80_35    | Aonly=  21980 Bonly=    406 both=    185 neither=  75321 | frac(A not B)=0.992  frac(B not A)=0.687
# TCP_MET        vs DITAU_80_60    | Aonly=  21959 Bonly=    198 both=    206 neither=  75529 | frac(A not B)=0.991  frac(B not A)=0.490
# J70            vs J75            | Aonly=    830 Bonly=      0 both=   2106 neither=  94956 | frac(A not B)=0.283  frac(B not A)=0.000
# J70            vs TAU+MET_PF     | Aonly=   1962 Bonly=   9649 both=    974 neither=  85307 | frac(A not B)=0.668  frac(B not A)=0.908
# J70            vs TAU+MET_TCP    | Aonly=   1957 Bonly=   9861 both=    979 neither=  85095 | frac(A not B)=0.667  frac(B not A)=0.910
# J70            vs TAU160         | Aonly=   2473 Bonly=   2652 both=    463 neither=  92304 | frac(A not B)=0.842  frac(B not A)=0.851
# J70            vs J_2J35         | Aonly=   2297 Bonly=   1912 both=    639 neither=  93044 | frac(A not B)=0.782  frac(B not A)=0.750
# J70            vs J_2J45         | Aonly=   2114 Bonly=   2427 both=    822 neither=  92529 | frac(A not B)=0.720  frac(B not A)=0.747
# J70            vs J140_2J50      | Aonly=   2195 Bonly=   1345 both=    741 neither=  93611 | frac(A not B)=0.748  frac(B not A)=0.645
# J70            vs J150_2J55      | Aonly=   2271 Bonly=   1078 both=    665 neither=  93878 | frac(A not B)=0.774  frac(B not A)=0.618
# J70            vs J175_J60       | Aonly=   2640 Bonly=    630 both=    296 neither=  94326 | frac(A not B)=0.899  frac(B not A)=0.680
# J70            vs DITAU_35_25    | Aonly=   2776 Bonly=   2951 both=    160 neither=  92005 | frac(A not B)=0.946  frac(B not A)=0.949
# J70            vs DITAU_35_25_J  | Aonly=   2818 Bonly=   2532 both=    118 neither=  92424 | frac(A not B)=0.960  frac(B not A)=0.955
# J70            vs DITAU_40_35    | Aonly=   2809 Bonly=   1511 both=    127 neither=  93445 | frac(A not B)=0.957  frac(B not A)=0.922
# J70            vs DITAU_80_35    | Aonly=   2862 Bonly=    517 both=     74 neither=  94439 | frac(A not B)=0.975  frac(B not A)=0.875
# J70            vs DITAU_80_60    | Aonly=   2866 Bonly=    334 both=     70 neither=  94622 | frac(A not B)=0.976  frac(B not A)=0.827
# J75            vs TAU+MET_PF     | Aonly=   1372 Bonly=   9889 both=    734 neither=  85897 | frac(A not B)=0.651  frac(B not A)=0.931
# J75            vs TAU+MET_TCP    | Aonly=   1369 Bonly=  10103 both=    737 neither=  85683 | frac(A not B)=0.650  frac(B not A)=0.932
# J75            vs TAU160         | Aonly=   1718 Bonly=   2727 both=    388 neither=  93059 | frac(A not B)=0.816  frac(B not A)=0.875
# J75            vs J_2J35         | Aonly=   1634 Bonly=   2079 both=    472 neither=  93707 | frac(A not B)=0.776  frac(B not A)=0.815
# J75            vs J_2J45         | Aonly=   1491 Bonly=   2634 both=    615 neither=  93152 | frac(A not B)=0.708  frac(B not A)=0.811
# J75            vs J140_2J50      | Aonly=   1497 Bonly=   1477 both=    609 neither=  94309 | frac(A not B)=0.711  frac(B not A)=0.708
# J75            vs J150_2J55      | Aonly=   1554 Bonly=   1191 both=    552 neither=  94595 | frac(A not B)=0.738  frac(B not A)=0.683
# J75            vs J175_J60       | Aonly=   1858 Bonly=    678 both=    248 neither=  95108 | frac(A not B)=0.882  frac(B not A)=0.732
# J75            vs DITAU_35_25    | Aonly=   1987 Bonly=   2992 both=    119 neither=  92794 | frac(A not B)=0.943  frac(B not A)=0.962
# J75            vs DITAU_35_25_J  | Aonly=   2016 Bonly=   2560 both=     90 neither=  93226 | frac(A not B)=0.957  frac(B not A)=0.966
# J75            vs DITAU_40_35    | Aonly=   2007 Bonly=   1539 both=     99 neither=  94247 | frac(A not B)=0.953  frac(B not A)=0.940
# J75            vs DITAU_80_35    | Aonly=   2044 Bonly=    529 both=     62 neither=  95257 | frac(A not B)=0.971  frac(B not A)=0.895
# J75            vs DITAU_80_60    | Aonly=   2044 Bonly=    342 both=     62 neither=  95444 | frac(A not B)=0.971  frac(B not A)=0.847
# TAU+MET_PF     vs TAU+MET_TCP    | Aonly=   1419 Bonly=   1636 both=   9204 neither=  85633 | frac(A not B)=0.134  frac(B not A)=0.151
# TAU+MET_PF     vs TAU160         | Aonly=   9439 Bonly=   1931 both=   1184 neither=  85338 | frac(A not B)=0.889  frac(B not A)=0.620
# TAU+MET_PF     vs J_2J35         | Aonly=  10122 Bonly=   2050 both=    501 neither=  85219 | frac(A not B)=0.953  frac(B not A)=0.804
# TAU+MET_PF     vs J_2J45         | Aonly=   9988 Bonly=   2614 both=    635 neither=  84655 | frac(A not B)=0.940  frac(B not A)=0.805
# TAU+MET_PF     vs J140_2J50      | Aonly=  10038 Bonly=   1501 both=    585 neither=  85768 | frac(A not B)=0.945  frac(B not A)=0.720
# TAU+MET_PF     vs J150_2J55      | Aonly=  10111 Bonly=   1231 both=    512 neither=  86038 | frac(A not B)=0.952  frac(B not A)=0.706
# TAU+MET_PF     vs J175_J60       | Aonly=  10389 Bonly=    692 both=    234 neither=  86577 | frac(A not B)=0.978  frac(B not A)=0.747
# TAU+MET_PF     vs DITAU_35_25    | Aonly=   9697 Bonly=   2185 both=    926 neither=  85084 | frac(A not B)=0.913  frac(B not A)=0.702
# TAU+MET_PF     vs DITAU_35_25_J  | Aonly=   9822 Bonly=   1849 both=    801 neither=  85420 | frac(A not B)=0.925  frac(B not A)=0.698
# TAU+MET_PF     vs DITAU_40_35    | Aonly=  10002 Bonly=   1017 both=    621 neither=  86252 | frac(A not B)=0.942  frac(B not A)=0.621
# TAU+MET_PF     vs DITAU_80_35    | Aonly=  10366 Bonly=    334 both=    257 neither=  86935 | frac(A not B)=0.976  frac(B not A)=0.565
# TAU+MET_PF     vs DITAU_80_60    | Aonly=  10388 Bonly=    169 both=    235 neither=  87100 | frac(A not B)=0.978  frac(B not A)=0.418
# TAU+MET_TCP    vs TAU160         | Aonly=   9536 Bonly=   1811 both=   1304 neither=  85241 | frac(A not B)=0.880  frac(B not A)=0.581
# TAU+MET_TCP    vs J_2J35         | Aonly=  10340 Bonly=   2051 both=    500 neither=  85001 | frac(A not B)=0.954  frac(B not A)=0.804
# TAU+MET_TCP    vs J_2J45         | Aonly=  10188 Bonly=   2597 both=    652 neither=  84455 | frac(A not B)=0.940  frac(B not A)=0.799
# TAU+MET_TCP    vs J140_2J50      | Aonly=  10241 Bonly=   1487 both=    599 neither=  85565 | frac(A not B)=0.945  frac(B not A)=0.713
# TAU+MET_TCP    vs J150_2J55      | Aonly=  10328 Bonly=   1231 both=    512 neither=  85821 | frac(A not B)=0.953  frac(B not A)=0.706
# TAU+MET_TCP    vs J175_J60       | Aonly=  10605 Bonly=    691 both=    235 neither=  86361 | frac(A not B)=0.978  frac(B not A)=0.746
# TAU+MET_TCP    vs DITAU_35_25    | Aonly=   9912 Bonly=   2183 both=    928 neither=  84869 | frac(A not B)=0.914  frac(B not A)=0.702
# TAU+MET_TCP    vs DITAU_35_25_J  | Aonly=  10048 Bonly=   1858 both=    792 neither=  85194 | frac(A not B)=0.927  frac(B not A)=0.701
# TAU+MET_TCP    vs DITAU_40_35    | Aonly=  10211 Bonly=   1009 both=    629 neither=  86043 | frac(A not B)=0.942  frac(B not A)=0.616
# TAU+MET_TCP    vs DITAU_80_35    | Aonly=  10568 Bonly=    319 both=    272 neither=  86733 | frac(A not B)=0.975  frac(B not A)=0.540
# TAU+MET_TCP    vs DITAU_80_60    | Aonly=  10597 Bonly=    161 both=    243 neither=  86891 | frac(A not B)=0.978  frac(B not A)=0.399
# TAU160         vs J_2J35         | Aonly=   2962 Bonly=   2398 both=    153 neither=  92379 | frac(A not B)=0.951  frac(B not A)=0.940
# TAU160         vs J_2J45         | Aonly=   2898 Bonly=   3032 both=    217 neither=  91745 | frac(A not B)=0.930  frac(B not A)=0.933
# TAU160         vs J140_2J50      | Aonly=   2797 Bonly=   1768 both=    318 neither=  93009 | frac(A not B)=0.898  frac(B not A)=0.848
# TAU160         vs J150_2J55      | Aonly=   2820 Bonly=   1448 both=    295 neither=  93329 | frac(A not B)=0.905  frac(B not A)=0.831
# TAU160         vs J175_J60       | Aonly=   2995 Bonly=    806 both=    120 neither=  93971 | frac(A not B)=0.961  frac(B not A)=0.870
# TAU160         vs DITAU_35_25    | Aonly=   2758 Bonly=   2754 both=    357 neither=  92023 | frac(A not B)=0.885  frac(B not A)=0.885
# TAU160         vs DITAU_35_25_J  | Aonly=   2853 Bonly=   2388 both=    262 neither=  92389 | frac(A not B)=0.916  frac(B not A)=0.901
# TAU160         vs DITAU_40_35    | Aonly=   2795 Bonly=   1318 both=    320 neither=  93459 | frac(A not B)=0.897  frac(B not A)=0.805
# TAU160         vs DITAU_80_35    | Aonly=   2907 Bonly=    383 both=    208 neither=  94394 | frac(A not B)=0.933  frac(B not A)=0.648
# TAU160         vs DITAU_80_60    | Aonly=   2868 Bonly=    157 both=    247 neither=  94620 | frac(A not B)=0.921  frac(B not A)=0.389
# J_2J35         vs J_2J45         | Aonly=    672 Bonly=   1370 both=   1879 neither=  93971 | frac(A not B)=0.263  frac(B not A)=0.422
# J_2J35         vs J140_2J50      | Aonly=   1816 Bonly=   1351 both=    735 neither=  93990 | frac(A not B)=0.712  frac(B not A)=0.648
# J_2J35         vs J150_2J55      | Aonly=   1944 Bonly=   1136 both=    607 neither=  94205 | frac(A not B)=0.762  frac(B not A)=0.652
# J_2J35         vs J175_J60       | Aonly=   2174 Bonly=    549 both=    377 neither=  94792 | frac(A not B)=0.852  frac(B not A)=0.593
# J_2J35         vs DITAU_35_25    | Aonly=   2364 Bonly=   2924 both=    187 neither=  92417 | frac(A not B)=0.927  frac(B not A)=0.940
# J_2J35         vs DITAU_35_25_J  | Aonly=   2412 Bonly=   2511 both=    139 neither=  92830 | frac(A not B)=0.946  frac(B not A)=0.948
# J_2J35         vs DITAU_40_35    | Aonly=   2455 Bonly=   1542 both=     96 neither=  93799 | frac(A not B)=0.962  frac(B not A)=0.941
# J_2J35         vs DITAU_80_35    | Aonly=   2510 Bonly=    550 both=     41 neither=  94791 | frac(A not B)=0.984  frac(B not A)=0.931
# J_2J35         vs DITAU_80_60    | Aonly=   2530 Bonly=    383 both=     21 neither=  94958 | frac(A not B)=0.992  frac(B not A)=0.948
# J_2J45         vs J140_2J50      | Aonly=   2104 Bonly=    941 both=   1145 neither=  93702 | frac(A not B)=0.648  frac(B not A)=0.451
# J_2J45         vs J150_2J55      | Aonly=   2290 Bonly=    784 both=    959 neither=  93859 | frac(A not B)=0.705  frac(B not A)=0.450
# J_2J45         vs J175_J60       | Aonly=   2642 Bonly=    319 both=    607 neither=  94324 | frac(A not B)=0.813  frac(B not A)=0.344
# J_2J45         vs DITAU_35_25    | Aonly=   3065 Bonly=   2927 both=    184 neither=  91716 | frac(A not B)=0.943  frac(B not A)=0.941
# J_2J45         vs DITAU_35_25_J  | Aonly=   3117 Bonly=   2518 both=    132 neither=  92125 | frac(A not B)=0.959  frac(B not A)=0.950
# J_2J45         vs DITAU_40_35    | Aonly=   3132 Bonly=   1521 both=    117 neither=  93122 | frac(A not B)=0.964  frac(B not A)=0.929
# J_2J45         vs DITAU_80_35    | Aonly=   3206 Bonly=    548 both=     43 neither=  94095 | frac(A not B)=0.987  frac(B not A)=0.927
# J_2J45         vs DITAU_80_60    | Aonly=   3221 Bonly=    376 both=     28 neither=  94267 | frac(A not B)=0.991  frac(B not A)=0.931
# J140_2J50      vs J150_2J55      | Aonly=    343 Bonly=      0 both=   1743 neither=  95806 | frac(A not B)=0.164  frac(B not A)=0.000
# J140_2J50      vs J175_J60       | Aonly=   1404 Bonly=    244 both=    682 neither=  95562 | frac(A not B)=0.673  frac(B not A)=0.263
# J140_2J50      vs DITAU_35_25    | Aonly=   1946 Bonly=   2971 both=    140 neither=  92835 | frac(A not B)=0.933  frac(B not A)=0.955
# J140_2J50      vs DITAU_35_25_J  | Aonly=   1983 Bonly=   2547 both=    103 neither=  93259 | frac(A not B)=0.951  frac(B not A)=0.961
# J140_2J50      vs DITAU_40_35    | Aonly=   1987 Bonly=   1539 both=     99 neither=  94267 | frac(A not B)=0.953  frac(B not A)=0.940
# J140_2J50      vs DITAU_80_35    | Aonly=   2032 Bonly=    537 both=     54 neither=  95269 | frac(A not B)=0.974  frac(B not A)=0.909
# J140_2J50      vs DITAU_80_60    | Aonly=   2043 Bonly=    361 both=     43 neither=  95445 | frac(A not B)=0.979  frac(B not A)=0.894
# J150_2J55      vs J175_J60       | Aonly=   1067 Bonly=    250 both=    676 neither=  95899 | frac(A not B)=0.612  frac(B not A)=0.270
# J150_2J55      vs DITAU_35_25    | Aonly=   1623 Bonly=   2991 both=    120 neither=  93158 | frac(A not B)=0.931  frac(B not A)=0.961
# J150_2J55      vs DITAU_35_25_J  | Aonly=   1657 Bonly=   2564 both=     86 neither=  93585 | frac(A not B)=0.951  frac(B not A)=0.968
# J150_2J55      vs DITAU_40_35    | Aonly=   1659 Bonly=   1554 both=     84 neither=  94595 | frac(A not B)=0.952  frac(B not A)=0.949
# J150_2J55      vs DITAU_80_35    | Aonly=   1698 Bonly=    546 both=     45 neither=  95603 | frac(A not B)=0.974  frac(B not A)=0.924
# J150_2J55      vs DITAU_80_60    | Aonly=   1704 Bonly=    365 both=     39 neither=  95784 | frac(A not B)=0.978  frac(B not A)=0.903
# J175_J60       vs DITAU_35_25    | Aonly=    869 Bonly=   3054 both=     57 neither=  93912 | frac(A not B)=0.938  frac(B not A)=0.982
# J175_J60       vs DITAU_35_25_J  | Aonly=    886 Bonly=   2610 both=     40 neither=  94356 | frac(A not B)=0.957  frac(B not A)=0.985
# J175_J60       vs DITAU_40_35    | Aonly=    884 Bonly=   1596 both=     42 neither=  95370 | frac(A not B)=0.955  frac(B not A)=0.974
# J175_J60       vs DITAU_80_35    | Aonly=    911 Bonly=    576 both=     15 neither=  96390 | frac(A not B)=0.984  frac(B not A)=0.975
# J175_J60       vs DITAU_80_60    | Aonly=    907 Bonly=    385 both=     19 neither=  96581 | frac(A not B)=0.979  frac(B not A)=0.953
# DITAU_35_25    vs DITAU_35_25_J  | Aonly=    910 Bonly=    449 both=   2201 neither=  94332 | frac(A not B)=0.293  frac(B not A)=0.169
# DITAU_35_25    vs DITAU_40_35    | Aonly=   1743 Bonly=    270 both=   1368 neither=  94511 | frac(A not B)=0.560  frac(B not A)=0.165
# DITAU_35_25    vs DITAU_80_35    | Aonly=   2604 Bonly=     84 both=    507 neither=  94697 | frac(A not B)=0.837  frac(B not A)=0.142
# DITAU_35_25    vs DITAU_80_60    | Aonly=   2804 Bonly=     97 both=    307 neither=  94684 | frac(A not B)=0.901  frac(B not A)=0.240
# DITAU_35_25_J  vs DITAU_40_35    | Aonly=   1531 Bonly=    519 both=   1119 neither=  94723 | frac(A not B)=0.578  frac(B not A)=0.317
# DITAU_35_25_J  vs DITAU_80_35    | Aonly=   2072 Bonly=     13 both=    578 neither=  95229 | frac(A not B)=0.782  frac(B not A)=0.022
# DITAU_35_25_J  vs DITAU_80_60    | Aonly=   2425 Bonly=    179 both=    225 neither=  95063 | frac(A not B)=0.915  frac(B not A)=0.443
# DITAU_40_35    vs DITAU_80_35    | Aonly=   1140 Bonly=     93 both=    498 neither=  96161 | frac(A not B)=0.696  frac(B not A)=0.157
# DITAU_40_35    vs DITAU_80_60    | Aonly=   1280 Bonly=     46 both=    358 neither=  96208 | frac(A not B)=0.781  frac(B not A)=0.114
# DITAU_80_35    vs DITAU_80_60    | Aonly=    374 Bonly=    187 both=    217 neither=  97114 | frac(A not B)=0.633  frac(B not A)=0.463

# %%
# binomial efficiency + 1-sigma uncertainty ----
def eff_err(passed, total):
    if total == 0:
        return np.nan, np.nan
    eff = passed / total
    err = np.sqrt(eff * (1 - eff) / total)
    return eff, err

bins = np.linspace(0, 350, 30)
centers = 0.5 * (bins[:-1] + bins[1:])

# choose a focused set to plot + quantify
focus = {
    "PF_MET": base["PF_MET"],
    "TCP_MET": base["TCP_MET"],
    "J70": base["J70"],
    "TAU+MET_PF": base["TAU+MET_PF"],
    "TAU+MET_TCP": base["TAU+MET_TCP"],
    "PF_MET OR J70": OR["PF_MET OR J70"],
    "PF_MET OR TAU+MET_PF": OR["PF_MET OR TAU+MET_PF"],
    "J70 OR TAU+MET_PF": OR["J70 OR TAU+MET_PF"],
    "PF_MET AND TAU+MET_PF": AND["PF_MET AND TAU+MET_PF"],
    "TAU160": base["TAU160"],
    "PF_MET OR TAU160": OR["PF_MET OR TAU160"],
    "J70 OR TAU160": OR["J70 OR TAU160"],
    # new triggers worth comparing on the turn-on plot
    "J_2J45": base["J_2J45"],
    "PF_MET OR J_2J45": OR["PF_MET OR J_2J45"],
    "DITAU_35_25": base["DITAU_35_25"],
    "PF_MET OR DITAU_35_25": OR["PF_MET OR DITAU_35_25"],
}

# storage
Nbin = []
out = {k: {"eff": [], "err": []} for k in focus.keys()}

for i in range(len(bins) - 1):
    lo, hi = bins[i], bins[i+1]
    sel = (offline_met_gev >= lo) & (offline_met_gev < hi)
    total = sel.sum()
    Nbin.append(total)

    for name, mask in focus.items():
        if total < 50:
            out[name]["eff"].append(np.nan)
            out[name]["err"].append(np.nan)
        else:
            passed = (mask & sel).sum()
            e, s = eff_err(passed, total)
            out[name]["eff"].append(e)
            out[name]["err"].append(s)

# plot with error bars
plt.figure(figsize=(10, 6))
for name in ["PF_MET", "TCP_MET", "J70", "TAU+MET_PF", "TAU+MET_TCP",
             "TAU160",
             "PF_MET OR J70", "PF_MET OR TAU+MET_PF", "J70 OR TAU+MET_PF",
             "PF_MET OR TAU160", "J70 OR TAU160",
             "J_2J45", "PF_MET OR J_2J45",
             "DITAU_35_25", "PF_MET OR DITAU_35_25"]:
    plt.errorbar(
        centers,
        out[name]["eff"],
        yerr=out[name]["err"],
        fmt="o",
        label=name
    )

plt.xlabel("Offline MET [GeV]")
plt.ylabel("Efficiency")
plt.ylim(0, 1.05)
plt.legend(fontsize=8, ncol=2)
plt.title(f"Trigger turn-on vs offline MET — {sample_label}")
plt.show()

# quantified table: 100–200 GeV
print("\n=== Per-bin quantification (100–200 GeV offline MET) ===")
print("bin[GeV]      N    PF_MET        TAU+MET_PF    PF_MET OR TAU+MET_PF  J70 OR TAU+MET_PF  PF_MET OR J_2J45  PF_MET OR DITAU_35_25")
print("-"*150)
for i in range(len(bins)-1):
    lo, hi = bins[i], bins[i+1]
    if lo < 100 or hi > 200:
        continue
    total = Nbin[i]
    if total < 50:
        continue

    def fmt(name):
        e = out[name]["eff"][i]
        s = out[name]["err"][i]
        return f"{e:6.3f}±{s:5.3f}"

    print(f"[{lo:5.1f},{hi:5.1f})  {total:5d}  "
          f"{fmt('PF_MET'):>12s}  "
          f"{fmt('TAU+MET_PF'):>12s}  "
          f"{fmt('PF_MET OR TAU+MET_PF'):>20s}  "
          f"{fmt('J70 OR TAU+MET_PF'):>17s}  "
          f"{fmt('PF_MET OR J_2J45'):>16s}  "
          f"{fmt('PF_MET OR DITAU_35_25'):>20s}")
# Out:
# === Per-bin quantification (100–200 GeV offline MET) ===
# bin[GeV]      N    PF_MET        TAU+MET_PF    PF_MET OR TAU+MET_PF  J70 OR TAU+MET_PF  PF_MET OR J_2J45  PF_MET OR DITAU_35_25
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [108.6,120.7)   6141   0.388±0.006   0.156±0.005           0.437±0.006        0.171±0.005       0.404±0.006           0.406±0.006
# [120.7,132.8)   5452   0.525±0.007   0.181±0.005           0.572±0.007        0.199±0.005       0.541±0.007           0.540±0.007
# [132.8,144.8)   4291   0.655±0.007   0.205±0.006           0.699±0.007        0.223±0.006       0.667±0.007           0.666±0.007
# [144.8,156.9)   3636   0.756±0.007   0.213±0.007           0.785±0.007        0.233±0.007       0.763±0.007           0.763±0.007
# [156.9,169.0)   3005   0.840±0.007   0.213±0.007           0.858±0.006        0.236±0.008       0.846±0.007           0.844±0.007
# [169.0,181.0)   2499   0.894±0.006   0.219±0.008           0.910±0.006        0.241±0.009       0.901±0.006           0.897±0.006
# [181.0,193.1)   2063   0.945±0.005   0.227±0.009           0.952±0.005        0.245±0.009       0.948±0.005           0.945±0.005

# %%
# tau trigger efficiency vs leading tau pt
lead_tau_pt = []
for i in range(len(df)):
    pts = df["tau_pt_NOSYS"][i]   # list of tau pts (MeV)
    if len(pts) > 0:
        lead_tau_pt.append(max(pts) / 1000.0)   # GeV
    else:
        lead_tau_pt.append(np.nan)

lead_tau_pt = np.array(lead_tau_pt)
print("lead tau pt min/max (GeV):", np.nanmin(lead_tau_pt), np.nanmax(lead_tau_pt))

bins_tau = np.linspace(0, 300, 31)
centers = []
eff_tau_pf_pt = []
eff_tau_tcp_pt = []
eff_tau160_pt = []

for i in range(len(bins_tau) - 1):
    lo = bins_tau[i]
    hi = bins_tau[i + 1]
    sel = (lead_tau_pt >= lo) & (lead_tau_pt < hi) & np.isfinite(lead_tau_pt)
    centers.append((lo + hi) / 2)

    if sel.sum() < 20:    # smaller cutoff so don't get a billion NaNs
        eff_tau_pf_pt.append(np.nan)
        eff_tau_tcp_pt.append(np.nan)
        eff_tau160_pt.append(np.nan)
    else:
        eff_tau_pf_pt.append(tau_pf[sel].mean())
        eff_tau_tcp_pt.append(tau_tcp[sel].mean())
        eff_tau160_pt.append(tau160[sel].mean())

plt.figure()
plt.plot(centers, eff_tau_pf_pt, "o", label="tau_pf")
plt.plot(centers, eff_tau_tcp_pt, "o", label="tau_tcp")
plt.plot(centers, eff_tau160_pt, "o", label="tau160")
plt.xlabel("leading tau pT")
plt.legend()
plt.title(f"Tau trigger efficiency vs leading tau pT — {sample_label}")

from pathlib import Path
PLOT_DIR = Path("plots")
PLOT_DIR.mkdir(exist_ok=True)

plt.savefig(PLOT_DIR / "170tau_pt_turnon_overlay.png",
            dpi=300,
            bbox_inches="tight")
plt.show()
# Out:
# lead tau pt min/max (GeV): 25.00020703125 675.36675

# %%
# b-tag trigger efficiency vs leading b-jet pt (b85 jets)
lead_bjet_pt = []
for i in range(len(df)):
    pts = df["jet_pt_NOSYS"][i]                          # jet pts (MeV)
    b85 = df["jet_GN2v01_FixedCutBEff_85_select"][i]     # 0/1 flags

    bpts = []
    for j in range(len(pts)):
        if b85[j] == 1:
            bpts.append(pts[j])

    if len(bpts) > 0:
        lead_bjet_pt.append(max(bpts) / 1000.0)          # GeV
    else:
        lead_bjet_pt.append(np.nan)

lead_bjet_pt = np.array(lead_bjet_pt)
print("lead b-jet pt min/max (GeV):", np.nanmin(lead_bjet_pt), np.nanmax(lead_bjet_pt))
print("fraction of events with >=1 b85 jet:", np.isfinite(lead_bjet_pt).mean())

bins_b = np.linspace(0, 400, 33)
centers = []
eff_j70_bpt = []
eff_j75_bpt = []

for i in range(len(bins_b) - 1):
    lo = bins_b[i]
    hi = bins_b[i + 1]
    sel = (lead_bjet_pt >= lo) & (lead_bjet_pt < hi) & np.isfinite(lead_bjet_pt)
    centers.append((lo + hi) / 2)

    if sel.sum() < 20:    # smaller cutoff because b-jets might be rarer????
        eff_j70_bpt.append(np.nan)
        eff_j75_bpt.append(np.nan)
    else:
        eff_j70_bpt.append(j70[sel].mean())
        eff_j75_bpt.append(j75[sel].mean())

plt.figure()
plt.plot(centers, eff_j70_bpt, "o", label="J70")
plt.plot(centers, eff_j75_bpt, "o", label="J75")
plt.xlabel("leading b-jet pT [GeV] (b85)")
plt.ylabel("efficiency")
plt.ylim(0, 1.05)
plt.legend()
plt.title("B-tag trigger efficiency vs leading b-jet pT")
plt.show()
# Out:
# lead b-jet pt min/max (GeV): 25.000482421875 1632.200625
# fraction of events with >=1 b85 jet: 0.743656274261431

# %%
print("Trigger Study Summary")

# basic efficiencies
print("Basic efficiencies:")
print(" PF-MET:", round(met_pf.mean(), 3))
print(" J70:",    round(j70.mean(), 3))
print(" J75:",    round(j75.mean(), 3))
print(" TAU pf:", round(tau_pf.mean(), 3))
print(" TAU tcp:", round(tau_tcp.mean(), 3))
print(" TAU160:",  round(tau160.mean(), 3))
# new triggers
print(" J_2J35:", round(j_2j35.mean(), 3))
print(" J_2J45:", round(j_2j45.mean(), 3))
print(" J140_2J50:", round(j140_2j50.mean(), 3))
print(" J150_2J55:", round(j150_2j55.mean(), 3))
print(" J175_J60:", round(j175_j60.mean(), 3))
print(" DITAU_35_25:", round(ditau_35_25.mean(), 3))
print(" DITAU_35_25_J:", round(ditau_35_25_j.mean(), 3))
print(" DITAU_40_35:", round(ditau_40_35.mean(), 3))
print(" DITAU_80_35:", round(ditau_80_35.mean(), 3))
print(" DITAU_80_60:", round(ditau_80_60.mean(), 3))
print()

# overlaps
print("Overlaps with PF-MET:")
j70_only = (j70 & ~met_pf).sum()
j75_only = (j75 & ~met_pf).sum()

if j70.sum() > 0:
    print(" frac(J70 not PF):", round(j70_only / j70.sum(), 3))
if j75.sum() > 0:
    print(" frac(J75 not PF):", round(j75_only / j75.sum(), 3))

tau_only = (tau_pf & ~met_pf).sum()
if tau_pf.sum() > 0:
    print(" frac(tau_pf not PF):", round(tau_only / tau_pf.sum(), 3))

tau160_only = (tau160 & ~met_pf).sum()
if tau160.sum() > 0:
    print(" frac(tau160 not PF):", round(tau160_only / tau160.sum(), 3))

# new-trigger overlaps with PF-MET
for name, mask in [("J_2J35", j_2j35), ("J_2J45", j_2j45),
                   ("J140_2J50", j140_2j50), ("J150_2J55", j150_2j55),
                   ("J175_J60", j175_j60),
                   ("DITAU_35_25", ditau_35_25),
                   ("DITAU_35_25_J", ditau_35_25_j),
                   ("DITAU_40_35", ditau_40_35),
                   ("DITAU_80_35", ditau_80_35),
                   ("DITAU_80_60", ditau_80_60)]:
    only = (mask & ~met_pf).sum()
    if mask.sum() > 0:
        print(f" frac({name} not PF):", round(only / mask.sum(), 3))

print()

# OR gains
print("OR efficiencies:")
print(" PF only:",                  round(met_pf.mean(), 3))
print(" PF OR J70:",                round((met_pf | j70).mean(), 3))
print(" PF OR J75:",                round((met_pf | j75).mean(), 3))
print(" PF OR J70 OR J75:",         round((met_pf | j70 | j75).mean(), 3))
print(" PF OR J70 OR tau:",         round((met_pf | j70 | tau_pf).mean(), 3))
print(" PF OR all (excl tau160):",  round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp).mean(), 3))
print(" PF OR all (incl tau160):",  round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp | tau160).mean(), 3))
print(" TAU160 OR PF_MET:",         round((tau160 | met_pf).mean(), 3))
print(" TAU160 OR J70:",            round((tau160 | j70).mean(), 3))
print()

# new-trigger OR gains
print(" PF OR J_2J45:",             round((met_pf | j_2j45).mean(), 3))
print(" PF OR J_2J35:",             round((met_pf | j_2j35).mean(), 3))
print(" PF OR J140_2J50:",          round((met_pf | j140_2j50).mean(), 3))
print(" PF OR DITAU_35_25:",        round((met_pf | ditau_35_25).mean(), 3))
print(" PF OR DITAU_40_35:",        round((met_pf | ditau_40_35).mean(), 3))
print(" PF OR all new b-tag:",      round((met_pf | j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60).mean(), 3))
print(" PF OR all new di-tau:",     round((met_pf | ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
print(" PF OR all new triggers:",   round((met_pf | j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60 |
                                            ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
print(" PF OR EVERYTHING:",         round((met_pf | met_hi | j70 | j75 | tau_pf | tau_tcp | tau160 |
                                            j_2j35 | j_2j45 | j140_2j50 | j150_2j55 | j175_j60 |
                                            ditau_35_25 | ditau_35_25_j | ditau_40_35 | ditau_80_35 | ditau_80_60).mean(), 3))
# Out:
# Trigger Study Summary
# Basic efficiencies:
#  PF-MET: 0.325
#  J70: 0.03
#  J75: 0.022
#  TAU pf: 0.109
#  TAU tcp: 0.111
#  TAU160: 0.032
#  J_2J35: 0.026
#  J_2J45: 0.033
#  J140_2J50: 0.021
#  J150_2J55: 0.018
#  J175_J60: 0.009
#  DITAU_35_25: 0.032
#  DITAU_35_25_J: 0.027
#  DITAU_40_35: 0.017
#  DITAU_80_35: 0.006
#  DITAU_80_60: 0.004
#
# Overlaps with PF-MET:
#  frac(J70 not PF): 0.502
#  frac(J75 not PF): 0.489
#  frac(tau_pf not PF): 0.231
#  frac(tau160 not PF): 0.684
#  frac(J_2J35 not PF): 0.588
#  frac(J_2J45 not PF): 0.572
#  frac(J140_2J50 not PF): 0.43
#  frac(J150_2J55 not PF): 0.415
#  frac(J175_J60 not PF): 0.362
#  frac(DITAU_35_25 not PF): 0.698
#  frac(DITAU_35_25_J not PF): 0.697
#  frac(DITAU_40_35 not PF): 0.665
#  frac(DITAU_80_35 not PF): 0.629
#  frac(DITAU_80_60 not PF): 0.46
#
# OR efficiencies:
#  PF only: 0.325
#  PF OR J70: 0.34
#  PF OR J75: 0.335
#  PF OR J70 OR J75: 0.34
#  PF OR J70 OR tau: 0.363
#  PF OR all (excl tau160): 0.383
#  PF OR all (incl tau160): 0.399
#  TAU160 OR PF_MET: 0.347
#  TAU160 OR J70: 0.057
#
#  PF OR J_2J45: 0.344
#  PF OR J_2J35: 0.34
#  PF OR J140_2J50: 0.334
#  PF OR DITAU_35_25: 0.347
#  PF OR DITAU_40_35: 0.336
#  PF OR all new b-tag: 0.352
#  PF OR all new di-tau: 0.351
#  PF OR all new triggers: 0.377
#  PF OR EVERYTHING: 0.437

# %%
#  Offline MET cut scan (100→200 GeV, 5 GeV steps) under PF MET trigger 

# Per the meeting: apply PF_MET trigger as the baseline, then sweep the
# offline MET threshold from 100 to 200 GeV in 5-GeV steps to see how
# much efficiency we lose/gain as that cut moves.

cut_values = np.arange(100, 205, 5)   # 100, 105, ..., 200 GeV

# Events that pass the PF MET trigger
pf_mask = met_pf.values    # boolean array

# Total events passing PF trigger (our denominator)
n_pf_total = pf_mask.sum()

effs = []
errors = []

for cut in cut_values:
    passed = (pf_mask & (offline_met_gev >= cut)).sum()
    eff, err = eff_err(passed, n_pf_total)
    effs.append(eff)
    errors.append(err)

effs = np.array(effs)
errors = np.array(errors)

#  Plot 
fig, ax = plt.subplots(figsize=(9, 5))

ax.errorbar(cut_values, effs, yerr=errors, fmt='o-', color='steelblue',
            capsize=3, label='PF MET trigger + offline cut')
ax.axvline(150, color='red', linestyle='--', label='Current cut (150 GeV)')

ax.set_xlabel('Offline MET cut [GeV]')
ax.set_ylabel('Efficiency (events passing trigger AND cut / events passing trigger)')
ax.set_ylim(0, 1.05)
ax.set_title(f'Efficiency vs offline MET cut — {sample_label} (PF MET baseline)')
ax.legend()
plt.tight_layout()
plt.show()

#  Numeric table 
print(f"\n=== Offline MET cut scan — {sample_label} (denominator = PF MET trigger events: {n_pf_total}) ===")
print(f"{'Cut [GeV]':>10}  {'Efficiency':>12}  {'Unc':>8}  {'Rel. to 150 GeV':>16}")
print("-" * 55)

ref_eff = effs[cut_values == 150][0]
for c, e, s in zip(cut_values, effs, errors):
    delta = e - ref_eff
    marker = " ← current" if c == 150 else ""
    print(f"{c:10.0f}  {e:12.4f}  {s:8.4f}  {delta:+.4f}{marker}")
# Out:
# === Offline MET cut scan — jet170 (denominator = PF MET trigger events: 31788) ===
#  Cut [GeV]    Efficiency       Unc   Rel. to 150 GeV
# -------------------------------------------------------
#        100        0.9041    0.0017  +0.3356
#        105        0.8797    0.0018  +0.3112
#        110        0.8531    0.0020  +0.2845
#        115        0.8238    0.0021  +0.2552
#        120        0.7909    0.0023  +0.2223
#        125        0.7545    0.0024  +0.1860
#        130        0.7167    0.0025  +0.1481
#        135        0.6784    0.0026  +0.1098
#        140        0.6418    0.0027  +0.0733
#        145        0.6059    0.0027  +0.0373
#        150        0.5685    0.0028  +0.0000 ← current
#        155        0.5344    0.0028  -0.0342
#        160        0.5000    0.0028  -0.0686
#        165        0.4671    0.0028  -0.1015
#        170        0.4351    0.0028  -0.1335
#        175        0.4056    0.0028  -0.1630
#        180        0.3765    0.0027  -0.1921
#        185        0.3490    0.0027  -0.2196
#        190        0.3232    0.0026  -0.2453
#        195        0.3011    0.0026  -0.2675
#        200        0.2793    0.0025  -0.2893
